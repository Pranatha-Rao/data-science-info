# %%
path
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-012ab3a6b187> in <module>
# ----> 1 path
#
# NameError: name 'path' is not defined

# %%
import matplotlib.pyplot as plt
import numpy as np
from IPython.core.display import HTML
from itertools import chain
from collections import Counter, defaultdict, namedtuple, OrderedDict
from pomegranate import State, HiddenMarkovModel, DiscreteDistribution
import os
from io import BytesIO
from itertools import chain
import random

# %% [markdown]
# # Sample code to generate Hindi and English tags similar to Brown model
# # This code breaks up the Hindi text into tags
#
#
# (Do not run this code - we have already generated the Tag files)
#
# file1 = open("Hindi_Split.txt","a")
# with open("Hindi_Test_New.txt", 'r') as f:
#         count = 1
#
#         file1.write("b1\n")
#         for l in f.read():
#             if (l == '’' or l == ','or l == '‘' or l == '--' or l == '"' or l == '-'):
#                 continue
#             if (l == '।' or l == '|') :
#                 count = count + 1
#                 file1.write("\n\nb" + str(count))
#             else:
#                 if l == ' ':
#                     file1.write("\n")
#                 else:
#
#
#                     file1.write(l)
#
#
#
# file1.close()
#
#
# fileHindiSplit = open("Hindi_Split.txt","r")
# fileEngSplit = open("Eng_Split.txt","r")
#
#
# hindiSplitList = [l for l in fileHindiSplit.read().split("\n")]
#
# engSplitList = [l for l in fileEngSplit.read().split("\n")]
#
#
#
# ### To generate Seperate Unique Tags
#
# fileHindiSplitNew = open("Hindi_Split 2.txt","r")
# for l in fileHindiSplitNew.read().split("\n"):
#     if l.startswith('b'):
#         continue
#     if l == '':
#         continue
#     if l not in hindi_unique_list:
#             hindi_unique_list.append(l)
#
#
# uniqueHindiTags = open("UniqueHindiTags.txt","a")
# for l in hindi_unique_list:
#     uniqueHindiTags.write(l + "\n")
#
# uniqueHindiTags.close()
#
#
# # Make sure there are equal number of tags in Hindi and Eng file
#
# hindiSplitList.pop()
#
#
# # Generate the final translation tag file
#
#
# fileFinal = open("FinalTags.txt","a")
#
# nCount = 0
#
# for i in range(1):
#
#     itemCount = 0
#     for x in hindiSplitList:
#
#             if (x == ''):
#                 itemCount = itemCount + 1
#                 continue
#             if (x.startswith('b')):
#                 fileFinal.write("\n")
#                 nCount = nCount+1
#                 fileFinal.write('b'+str(nCount) + "\n")
#             else:
#                 fileFinal.write(x + "\t" + engSplitList[itemCount].replace(" ","") + "\n")
#             itemCount = itemCount + 1
#
# fileFinal.close()

# %%
# Read the Hindi English file and the English tag file

# %%
def read_data(filename):
    """Read tagged sentence data"""
    with open(filename, 'r') as f:
        sentence_lines = [l.split("\n") for l in f.read().split("\n\n")]
        # New Code
        sentence_lines = sentence_lines[1:(len(sentence_lines))-1]
    return OrderedDict(((s[0], Sentence(*zip(*[l.strip().split("\t")
                  for l in s[1:]]))) for s in sentence_lines if s[0]))
        
    
    

def read_tags(filename):
    """Read a list of word tag classes"""
    with open(filename, 'r') as f:
        tags = f.read().split("\n")
    return frozenset(tags)

Sentence = namedtuple("Sentence", "words tags")

# %%
tagset = read_tags("EngUnique.txt")
sentences = read_data("FinalTags.txt")


sentences
# Out:
# OrderedDict([('b242',
#               Sentence(words=('एक', 'गमले', 'में', 'छोटे', 'पीले', 'संतरे', 'तो', 'दूसरे', 'में', 'एक', 'सेब', 'और', 'तीसरे', 'में', 'एक', 'नीबू', 'लटका', 'था'), tags=('One', 'flowerpot', 'In', 'Small', 'Yellow', 'Oranges', 'so', 'Others', 'In', 'One', 'Apple', 'And', 'Third', 'In', 'One', 'lemon', 'Hang', 'Was'))),
#              ('b243',
#               Sentence(words=('बीच', 'में', 'हरीहरी', 'घास', 'ही', 'घास', 'थी'), tags=('between', 'In', 'Green', 'Grass', 'Only', 'Grass', 'was'))),
#              ('b244',
#               Sentence(words=('शाम', 'के', 'समय', 'कभी', 'पापा', 'कभी', 'बुआ', 'कभी', 'मम्मी', 'के', 'साथ', 'वह', 'टेनिस', 'बैडमिंटन', 'या', 'फुटबॉल', 'खेलता', 'था'), tags=('evening', 'Of', 'Time', 'sometimes', 'dad', 'sometimes', "father'ssister", 'sometimes', 'Mummy', 'Of', 'with', 'that', 'Tennis', 'Badminton', 'or', 'Football', 'Plays', 'Was'))),
#              ('b245',
#               Sentence(words=('सबके', 'साथ', 'वह', 'खूब', 'मस्ती', 'करता'), tags=('Toeveryone', 'with', 'that', 'Plenty', 'fun', 'Does'))),
#              ('b246',
#               Sentence(words=('टीवी', 'पर', 'फुटबॉल', 'खिलाड़ियों', 'को', 'देख', 'कुछकुछ', 'वैसे', 'ही', 'करतब', 'करने', 'की', 'कोशिश', 'करता'), tags=('TV', 'On', 'Football', 'Theplayers', 'To', 'See', 'something', 'bytheway', 'Only', 'Feat', 'Todo', 'Of', 'try', 'Does'))),
#              ('b247',
#               Sentence(words=('उसके', 'बाद', 'दिन', 'के', 'वक्त', 'दादाजी', 'के', 'साथ', 'शतरंज', 'खेलता'), tags=('his', 'after', 'day', 'Of', 'time', 'grandfatherSir', 'Of', 'with', 'Chess', 'Plays'))),
#              ('b248',
#               Sentence(words=('खेलते', 'वक्त', 'दादाजी', 'उससे', 'कहते', 'देखो', 'अगर', 'तुम', 'यह', 'चाल', 'चलोगे', 'तो', 'मैं', 'तुम्हारे', 'घोड़े', 'को', 'मार', 'दूंगा'), tags=('Play', 'time', 'grandfatherSir', 'Fromhim', 'Say', 'Look', 'if', 'you', 'this', 'Trick', 'Willyougo', 'so', 'Iam', 'Your', 'Thehorses', 'To', 'Kill', 'Give'))),
#              ('b249',
#               Sentence(words=('दादाजी', 'उसे', 'हर', 'हाल', 'में', 'जिता', 'देना', 'चाहते', 'थे'), tags=('grandfatherSir', 'Him', 'every', 'condition', 'In', 'Jita', 'give', 'Want', 'Were'))),
#              ('b250', Sentence(words=('सब', 'हंसते'), tags=('All', 'Laughs'))),
#              ('b251',
#               Sentence(words=('जब', 'अंतरिक्ष', 'उन्हें', 'उनके', 'ही', 'बताए', 'खेल', 'से', 'हरा', 'देता', 'तो', 'वह', 'झूठमूठ', 'रोने', 'की', 'एक्टिंग', 'करते', 'हुए', 'कहते', 'अरे', 'यह', 'लड़का', 'तो', 'बहुत', 'तेज', 'हो', 'गया', 'है'), tags=('when', 'Space', 'them', 'Their', 'Only', 'Tell', 'sport', 'From', 'Green', 'Gives', 'so', 'that', 'Alie', 'Tocry', 'Of', 'Acting', 'do', 'Happened', 'Say', 'Hey', 'this', 'Theboy', 'so', 'very', 'fast', 'Ho', 'Gone', 'is'))),
#              ('b266',
#               Sentence(words=('पापा', 'बोले', 'मुझे', 'तो', 'लगता', 'है', 'इसकी', 'फुटबॉल', 'स्पेसशिप', 'बनकर', 'चांद', 'पर', 'चली', 'गई', 'है'), tags=('dad', 'Speak', 'me', 'so', 'Seems', 'is', 'his', 'Football', 'Spaceship', 'bemade', 'Themoon', 'On', 'Lasted', 'Hasgone', 'is'))),
#              ('b307',
#               Sentence(words=('हां', 'पापा', 'नंबर', 'दो', 'उसका'), tags=('Yes', 'dad', 'Number', 'two', 'His'))),
#              ('b308',
#               Sentence(words=('मैं', 'पूछूंगा'), tags=('Iam', 'Willask'))),
#              ('b309',
#               Sentence(words=('ठीक', 'है', 'ठीक', 'है'), tags=('Fine', 'is', 'Fine', 'is'))),
#              ('b1',
#               Sentence(words=('अंतरिक्ष', 'के', 'बगीचे', 'में', 'त'), tags=('Space', 'Of', 'Thegarden', 'In', 'T'))),
#              ('b2',
#               Sentence(words=('अंतरिक्ष', 'के', 'बगीचे', 'त', 'में'), tags=('Space', 'Of', 'Thegarden', 'T', 'In'))),
#              ('b3',
#               Sentence(words=('अंतरिक्ष', 'के', 'में', 'बगीचे', 'त'), tags=('Space', 'Of', 'In', 'Thegarden', 'T'))),
#              ('b4',
#               Sentence(words=('अंतरिक्ष', 'के', 'में', 'त', 'बगीचे'), tags=('Space', 'Of', 'In', 'T', 'Thegarden'))),
#              ('b5',
#               Sentence(words=('अंतरिक्ष', 'के', 'त', 'बगीचे', 'में'), tags=('Space', 'Of', 'T', 'Thegarden', 'In'))),
#              ('b6',
#               Sentence(words=('अंतरिक्ष', 'के', 'त', 'में', 'बगीचे'), tags=('Space', 'Of', 'T', 'In', 'Thegarden'))),
#              ('b7',
#               Sentence(words=('अंतरिक्ष', 'बगीचे', 'के', 'में', 'त'), tags=('Space', 'Thegarden', 'Of', 'In', 'T'))),
#              ('b8',
#               Sentence(words=('अंतरिक्ष', 'बगीचे', 'के', 'त', 'में'), tags=('Space', 'Thegarden', 'Of', 'T', 'In'))),
#              ('b9',
#               Sentence(words=('अंतरिक्ष', 'बगीचे', 'में', 'के', 'त'), tags=('Space', 'Thegarden', 'In', 'Of', 'T'))),
#              ('b10',
#               Sentence(words=('अंतरिक्ष', 'बगीचे', 'में', 'त', 'के'), tags=('Space', 'Thegarden', 'In', 'T', 'Of'))),
#              ('b11',
#               Sentence(words=('अंतरिक्ष', 'बगीचे', 'त', 'के', 'में'), tags=('Space', 'Thegarden', 'T', 'Of', 'In'))),
#              ('b12',
#               Sentence(words=('अंतरिक्ष', 'बगीचे', 'त', 'में', 'के'), tags=('Space', 'Thegarden', 'T', 'In', 'Of'))),
#              ('b13',
#               Sentence(words=('अंतरिक्ष', 'में', 'के', 'बगीचे', 'त'), tags=('Space', 'In', 'Of', 'Thegarden', 'T'))),
#              ('b14',
#               Sentence(words=('अंतरिक्ष', 'में', 'के', 'त', 'बगीचे'), tags=('Space', 'In', 'Of', 'T', 'Thegarden'))),
#              ('b15',
#               Sentence(words=('अंतरिक्ष', 'में', 'बगीचे', 'के', 'त'), tags=('Space', 'In', 'Thegarden', 'Of', 'T'))),
#              ('b16',
#               Sentence(words=('अंतरिक्ष', 'में', 'बगीचे', 'त', 'के'), tags=('Space', 'In', 'Thegarden', 'T', 'Of'))),
#              ('b17',
#               Sentence(words=('अंतरिक्ष', 'में', 'त', 'के', 'बगीचे'), tags=('Space', 'In', 'T', 'Of', 'Thegarden'))),
#              ('b18',
#               Sentence(words=('अंतरिक्ष', 'में', 'त', 'बगीचे', 'के'), tags=('Space', 'In', 'T', 'Thegarden', 'Of'))),
#              ('b19',
#               Sentence(words=('अंतरिक्ष', 'त', 'के', 'बगीचे', 'में'), tags=('Space', 'T', 'Of', 'Thegarden', 'In'))),
#              ('b20',
#               Sentence(words=('अंतरिक्ष', 'त', 'के', 'में', 'बगीचे'), tags=('Space', 'T', 'Of', 'In', 'Thegarden'))),
#              ('b21',
#               Sentence(words=('अंतरिक्ष', 'त', 'बगीचे', 'के', 'में'), tags=('Space', 'T', 'Thegarden', 'Of', 'In'))),
#              ('b22',
#               Sentence(words=('अंतरिक्ष', 'त', 'बगीचे', 'में', 'के'), tags=('Space', 'T', 'Thegarden', 'In', 'Of'))),
#              ('b23',
#               Sentence(words=('अंतरिक्ष', 'त', 'में', 'के', 'बगीचे'), tags=('Space', 'T', 'In', 'Of', 'Thegarden'))),
#              ('b24',
#               Sentence(words=('अंतरिक्ष', 'त', 'में', 'बगीचे', 'के'), tags=('Space', 'T', 'In', 'Thegarden', 'Of'))),
#              ('b25',
#               Sentence(words=('के', 'अंतरिक्ष', 'बगीचे', 'में', 'त'), tags=('Of', 'Space', 'Thegarden', 'In', 'T'))),
#              ('b26',
#               Sentence(words=('के', 'अंतरिक्ष', 'बगीचे', 'त', 'में'), tags=('Of', 'Space', 'Thegarden', 'T', 'In'))),
#              ('b27',
#               Sentence(words=('के', 'अंतरिक्ष', 'में', 'बगीचे', 'त'), tags=('Of', 'Space', 'In', 'Thegarden', 'T'))),
#              ('b28',
#               Sentence(words=('के', 'अंतरिक्ष', 'में', 'त', 'बगीचे'), tags=('Of', 'Space', 'In', 'T', 'Thegarden'))),
#              ('b29',
#               Sentence(words=('के', 'अंतरिक्ष', 'त', 'बगीचे', 'में'), tags=('Of', 'Space', 'T', 'Thegarden', 'In'))),
#              ('b30',
#               Sentence(words=('के', 'अंतरिक्ष', 'त', 'में', 'बगीचे'), tags=('Of', 'Space', 'T', 'In', 'Thegarden'))),
#              ('b31',
#               Sentence(words=('के', 'बगीचे', 'अंतरिक्ष', 'में', 'त'), tags=('Of', 'Thegarden', 'Space', 'In', 'T'))),
#              ('b32',
#               Sentence(words=('के', 'बगीचे', 'अंतरिक्ष', 'त', 'में'), tags=('Of', 'Thegarden', 'Space', 'T', 'In'))),
#              ('b33',
#               Sentence(words=('के', 'बगीचे', 'में', 'अंतरिक्ष', 'त'), tags=('Of', 'Thegarden', 'In', 'Space', 'T'))),
#              ('b34',
#               Sentence(words=('के', 'बगीचे', 'में', 'त', 'अंतरिक्ष'), tags=('Of', 'Thegarden', 'In', 'T', 'Space'))),
#              ('b35',
#               Sentence(words=('के', 'बगीचे', 'त', 'अंतरिक्ष', 'में'), tags=('Of', 'Thegarden', 'T', 'Space', 'In'))),
#              ('b36',
#               Sentence(words=('के', 'बगीचे', 'त', 'में', 'अंतरिक्ष'), tags=('Of', 'Thegarden', 'T', 'In', 'Space'))),
#              ('b37',
#               Sentence(words=('के', 'में', 'अंतरिक्ष', 'बगीचे', 'त'), tags=('Of', 'In', 'Space', 'Thegarden', 'T'))),
#              ('b38',
#               Sentence(words=('के', 'में', 'अंतरिक्ष', 'त', 'बगीचे'), tags=('Of', 'In', 'Space', 'T', 'Thegarden'))),
#              ('b39',
#               Sentence(words=('के', 'में', 'बगीचे', 'अंतरिक्ष', 'त'), tags=('Of', 'In', 'Thegarden', 'Space', 'T'))),
#              ('b40',
#               Sentence(words=('के', 'में', 'बगीचे', 'त', 'अंतरिक्ष'), tags=('Of', 'In', 'Thegarden', 'T', 'Space'))),
#              ('b41',
#               Sentence(words=('के', 'में', 'त', 'अंतरिक्ष', 'बगीचे'), tags=('Of', 'In', 'T', 'Space', 'Thegarden'))),
#              ('b42',
#               Sentence(words=('के', 'में', 'त', 'बगीचे', 'अंतरिक्ष'), tags=('Of', 'In', 'T', 'Thegarden', 'Space'))),
#              ('b43',
#               Sentence(words=('के', 'त', 'अंतरिक्ष', 'बगीचे', 'में'), tags=('Of', 'T', 'Space', 'Thegarden', 'In'))),
#              ('b44',
#               Sentence(words=('के', 'त', 'अंतरिक्ष', 'में', 'बगीचे'), tags=('Of', 'T', 'Space', 'In', 'Thegarden'))),
#              ('b45',
#               Sentence(words=('के', 'त', 'बगीचे', 'अंतरिक्ष', 'में'), tags=('Of', 'T', 'Thegarden', 'Space', 'In'))),
#              ('b46',
#               Sentence(words=('के', 'त', 'बगीचे', 'में', 'अंतरिक्ष'), tags=('Of', 'T', 'Thegarden', 'In', 'Space'))),
#              ('b47',
#               Sentence(words=('के', 'त', 'में', 'अंतरिक्ष', 'बगीचे'), tags=('Of', 'T', 'In', 'Space', 'Thegarden'))),
#              ('b48',
#               Sentence(words=('के', 'त', 'में', 'बगीचे', 'अंतरिक्ष'), tags=('Of', 'T', 'In', 'Thegarden', 'Space'))),
#              ('b49',
#               Sentence(words=('बगीचे', 'अंतरिक्ष', 'के', 'में', 'त'), tags=('Thegarden', 'Space', 'Of', 'In', 'T'))),
#              ('b50',
#               Sentence(words=('बगीचे', 'अंतरिक्ष', 'के', 'त', 'में'), tags=('Thegarden', 'Space', 'Of', 'T', 'In'))),
#              ('b51',
#               Sentence(words=('बगीचे', 'अंतरिक्ष', 'में', 'के', 'त'), tags=('Thegarden', 'Space', 'In', 'Of', 'T'))),
#              ('b52',
#               Sentence(words=('बगीचे', 'अंतरिक्ष', 'में', 'त', 'के'), tags=('Thegarden', 'Space', 'In', 'T', 'Of'))),
#              ('b53',
#               Sentence(words=('बगीचे', 'अंतरिक्ष', 'त', 'के', 'में'), tags=('Thegarden', 'Space', 'T', 'Of', 'In'))),
#              ('b54',
#               Sentence(words=('बगीचे', 'अंतरिक्ष', 'त', 'में', 'के'), tags=('Thegarden', 'Space', 'T', 'In', 'Of'))),
#              ('b55',
#               Sentence(words=('बगीचे', 'के', 'अंतरिक्ष', 'में', 'त'), tags=('Thegarden', 'Of', 'Space', 'In', 'T'))),
#              ('b56',
#               Sentence(words=('बगीचे', 'के', 'अंतरिक्ष', 'त', 'में'), tags=('Thegarden', 'Of', 'Space', 'T', 'In'))),
#              ('b57',
#               Sentence(words=('बगीचे', 'के', 'में', 'अंतरिक्ष', 'त'), tags=('Thegarden', 'Of', 'In', 'Space', 'T'))),
#              ('b58',
#               Sentence(words=('बगीचे', 'के', 'में', 'त', 'अंतरिक्ष'), tags=('Thegarden', 'Of', 'In', 'T', 'Space'))),
#              ('b59',
#               Sentence(words=('बगीचे', 'के', 'त', 'अंतरिक्ष', 'में'), tags=('Thegarden', 'Of', 'T', 'Space', 'In'))),
#              ('b60',
#               Sentence(words=('बगीचे', 'के', 'त', 'में', 'अंतरिक्ष'), tags=('Thegarden', 'Of', 'T', 'In', 'Space'))),
#              ('b61',
#               Sentence(words=('बगीचे', 'में', 'अंतरिक्ष', 'के', 'त'), tags=('Thegarden', 'In', 'Space', 'Of', 'T'))),
#              ('b62',
#               Sentence(words=('बगीचे', 'में', 'अंतरिक्ष', 'त', 'के'), tags=('Thegarden', 'In', 'Space', 'T', 'Of'))),
#              ('b63',
#               Sentence(words=('बगीचे', 'में', 'के', 'अंतरिक्ष', 'त'), tags=('Thegarden', 'In', 'Of', 'Space', 'T'))),
#              ('b64',
#               Sentence(words=('बगीचे', 'में', 'के', 'त', 'अंतरिक्ष'), tags=('Thegarden', 'In', 'Of', 'T', 'Space'))),
#              ('b65',
#               Sentence(words=('बगीचे', 'में', 'त', 'अंतरिक्ष', 'के'), tags=('Thegarden', 'In', 'T', 'Space', 'Of'))),
#              ('b66',
#               Sentence(words=('बगीचे', 'में', 'त', 'के', 'अंतरिक्ष'), tags=('Thegarden', 'In', 'T', 'Of', 'Space'))),
#              ('b67',
#               Sentence(words=('बगीचे', 'त', 'अंतरिक्ष', 'के', 'में'), tags=('Thegarden', 'T', 'Space', 'Of', 'In'))),
#              ('b68',
#               Sentence(words=('बगीचे', 'त', 'अंतरिक्ष', 'में', 'के'), tags=('Thegarden', 'T', 'Space', 'In', 'Of'))),
#              ('b69',
#               Sentence(words=('बगीचे', 'त', 'के', 'अंतरिक्ष', 'में'), tags=('Thegarden', 'T', 'Of', 'Space', 'In'))),
#              ('b70',
#               Sentence(words=('बगीचे', 'त', 'के', 'में', 'अंतरिक्ष'), tags=('Thegarden', 'T', 'Of', 'In', 'Space'))),
#              ('b71',
#               Sentence(words=('बगीचे', 'त', 'में', 'अंतरिक्ष', 'के'), tags=('Thegarden', 'T', 'In', 'Space', 'Of'))),
#              ('b72',
#               Sentence(words=('बगीचे', 'त', 'में', 'के', 'अंतरिक्ष'), tags=('Thegarden', 'T', 'In', 'Of', 'Space'))),
#              ('b73',
#               Sentence(words=('में', 'अंतरिक्ष', 'के', 'बगीचे', 'त'), tags=('In', 'Space', 'Of', 'Thegarden', 'T'))),
#              ('b74',
#               Sentence(words=('में', 'अंतरिक्ष', 'के', 'त', 'बगीचे'), tags=('In', 'Space', 'Of', 'T', 'Thegarden'))),
#              ('b75',
#               Sentence(words=('में', 'अंतरिक्ष', 'बगीचे', 'के', 'त'), tags=('In', 'Space', 'Thegarden', 'Of', 'T'))),
#              ('b76',
#               Sentence(words=('में', 'अंतरिक्ष', 'बगीचे', 'त', 'के'), tags=('In', 'Space', 'Thegarden', 'T', 'Of'))),
#              ('b77',
#               Sentence(words=('में', 'अंतरिक्ष', 'त', 'के', 'बगीचे'), tags=('In', 'Space', 'T', 'Of', 'Thegarden'))),
#              ('b78',
#               Sentence(words=('में', 'अंतरिक्ष', 'त', 'बगीचे', 'के'), tags=('In', 'Space', 'T', 'Thegarden', 'Of'))),
#              ('b79',
#               Sentence(words=('में', 'के', 'अंतरिक्ष', 'बगीचे', 'त'), tags=('In', 'Of', 'Space', 'Thegarden', 'T'))),
#              ('b80',
#               Sentence(words=('में', 'के', 'अंतरिक्ष', 'त', 'बगीचे'), tags=('In', 'Of', 'Space', 'T', 'Thegarden'))),
#              ('b81',
#               Sentence(words=('में', 'के', 'बगीचे', 'अंतरिक्ष', 'त'), tags=('In', 'Of', 'Thegarden', 'Space', 'T'))),
#              ('b82',
#               Sentence(words=('में', 'के', 'बगीचे', 'त', 'अंतरिक्ष'), tags=('In', 'Of', 'Thegarden', 'T', 'Space'))),
#              ('b83',
#               Sentence(words=('में', 'के', 'त', 'अंतरिक्ष', 'बगीचे'), tags=('In', 'Of', 'T', 'Space', 'Thegarden'))),
#              ('b84',
#               Sentence(words=('में', 'के', 'त', 'बगीचे', 'अंतरिक्ष'), tags=('In', 'Of', 'T', 'Thegarden', 'Space'))),
#              ('b85',
#               Sentence(words=('में', 'बगीचे', 'अंतरिक्ष', 'के', 'त'), tags=('In', 'Thegarden', 'Space', 'Of', 'T'))),
#              ('b86',
#               Sentence(words=('में', 'बगीचे', 'अंतरिक्ष', 'त', 'के'), tags=('In', 'Thegarden', 'Space', 'T', 'Of'))),
#              ('b87',
#               Sentence(words=('में', 'बगीचे', 'के', 'अंतरिक्ष', 'त'), tags=('In', 'Thegarden', 'Of', 'Space', 'T'))),
#              ('b88',
#               Sentence(words=('में', 'बगीचे', 'के', 'त', 'अंतरिक्ष'), tags=('In', 'Thegarden', 'Of', 'T', 'Space'))),
#              ('b89',
#               Sentence(words=('में', 'बगीचे', 'त', 'अंतरिक्ष', 'के'), tags=('In', 'Thegarden', 'T', 'Space', 'Of'))),
#              ('b90',
#               Sentence(words=('में', 'बगीचे', 'त', 'के', 'अंतरिक्ष'), tags=('In', 'Thegarden', 'T', 'Of', 'Space'))),
#              ('b91',
#               Sentence(words=('में', 'त', 'अंतरिक्ष', 'के', 'बगीचे'), tags=('In', 'T', 'Space', 'Of', 'Thegarden'))),
#              ('b92',
#               Sentence(words=('में', 'त', 'अंतरिक्ष', 'बगीचे', 'के'), tags=('In', 'T', 'Space', 'Thegarden', 'Of'))),
#              ('b93',
#               Sentence(words=('में', 'त', 'के', 'अंतरिक्ष', 'बगीचे'), tags=('In', 'T', 'Of', 'Space', 'Thegarden'))),
#              ('b94',
#               Sentence(words=('में', 'त', 'के', 'बगीचे', 'अंतरिक्ष'), tags=('In', 'T', 'Of', 'Thegarden', 'Space'))),
#              ('b95',
#               Sentence(words=('में', 'त', 'बगीचे', 'अंतरिक्ष', 'के'), tags=('In', 'T', 'Thegarden', 'Space', 'Of'))),
#              ('b96',
#               Sentence(words=('में', 'त', 'बगीचे', 'के', 'अंतरिक्ष'), tags=('In', 'T', 'Thegarden', 'Of', 'Space'))),
#              ('b97',
#               Sentence(words=('त', 'अंतरिक्ष', 'के', 'बगीचे', 'में'), tags=('T', 'Space', 'Of', 'Thegarden', 'In'))),
#              ('b98',
#               Sentence(words=('त', 'अंतरिक्ष', 'के', 'में', 'बगीचे'), tags=('T', 'Space', 'Of', 'In', 'Thegarden'))),
#              ('b99',
#               Sentence(words=('त', 'अंतरिक्ष', 'बगीचे', 'के', 'में'), tags=('T', 'Space', 'Thegarden', 'Of', 'In'))),
#              ('b100',
#               Sentence(words=('त', 'अंतरिक्ष', 'बगीचे', 'में', 'के'), tags=('T', 'Space', 'Thegarden', 'In', 'Of'))),
#              ('b101',
#               Sentence(words=('त', 'अंतरिक्ष', 'में', 'के', 'बगीचे'), tags=('T', 'Space', 'In', 'Of', 'Thegarden'))),
#              ('b102',
#               Sentence(words=('त', 'अंतरिक्ष', 'में', 'बगीचे', 'के'), tags=('T', 'Space', 'In', 'Thegarden', 'Of'))),
#              ('b103',
#               Sentence(words=('त', 'के', 'अंतरिक्ष', 'बगीचे', 'में'), tags=('T', 'Of', 'Space', 'Thegarden', 'In'))),
#              ('b104',
#               Sentence(words=('त', 'के', 'अंतरिक्ष', 'में', 'बगीचे'), tags=('T', 'Of', 'Space', 'In', 'Thegarden'))),
#              ('b105',
#               Sentence(words=('त', 'के', 'बगीचे', 'अंतरिक्ष', 'में'), tags=('T', 'Of', 'Thegarden', 'Space', 'In'))),
#              ('b106',
#               Sentence(words=('त', 'के', 'बगीचे', 'में', 'अंतरिक्ष'), tags=('T', 'Of', 'Thegarden', 'In', 'Space'))),
#              ('b107',
#               Sentence(words=('त', 'के', 'में', 'अंतरिक्ष', 'बगीचे'), tags=('T', 'Of', 'In', 'Space', 'Thegarden'))),
#              ('b108',
#               Sentence(words=('त', 'के', 'में', 'बगीचे', 'अंतरिक्ष'), tags=('T', 'Of', 'In', 'Thegarden', 'Space'))),
#              ('b109',
#               Sentence(words=('त', 'बगीचे', 'अंतरिक्ष', 'के', 'में'), tags=('T', 'Thegarden', 'Space', 'Of', 'In'))),
#              ('b110',
#               Sentence(words=('त', 'बगीचे', 'अंतरिक्ष', 'में', 'के'), tags=('T', 'Thegarden', 'Space', 'In', 'Of'))),
#              ('b111',
#               Sentence(words=('त', 'बगीचे', 'के', 'अंतरिक्ष', 'में'), tags=('T', 'Thegarden', 'Of', 'Space', 'In'))),
#              ('b112',
#               Sentence(words=('त', 'बगीचे', 'के', 'में', 'अंतरिक्ष'), tags=('T', 'Thegarden', 'Of', 'In', 'Space'))),
#              ('b113',
#               Sentence(words=('त', 'बगीचे', 'में', 'अंतरिक्ष', 'के'), tags=('T', 'Thegarden', 'In', 'Space', 'Of'))),
#              ('b114',
#               Sentence(words=('त', 'बगीचे', 'में', 'के', 'अंतरिक्ष'), tags=('T', 'Thegarden', 'In', 'Of', 'Space'))),
#              ('b115',
#               Sentence(words=('त', 'में', 'अंतरिक्ष', 'के', 'बगीचे'), tags=('T', 'In', 'Space', 'Of', 'Thegarden'))),
#              ('b116',
#               Sentence(words=('त', 'में', 'अंतरिक्ष', 'बगीचे', 'के'), tags=('T', 'In', 'Space', 'Thegarden', 'Of'))),
#              ('b117',
#               Sentence(words=('त', 'में', 'के', 'अंतरिक्ष', 'बगीचे'), tags=('T', 'In', 'Of', 'Space', 'Thegarden'))),
#              ('b118',
#               Sentence(words=('त', 'में', 'के', 'बगीचे', 'अंतरिक्ष'), tags=('T', 'In', 'Of', 'Thegarden', 'Space'))),
#              ('b119',
#               Sentence(words=('त', 'में', 'बगीचे', 'अंतरिक्ष', 'के'), tags=('T', 'In', 'Thegarden', 'Space', 'Of'))),
#              ('b120',
#               Sentence(words=('त', 'में', 'बगीचे', 'के', 'अंतरिक्ष'), tags=('T', 'In', 'Thegarden', 'Of', 'Space'))),
#              ('b122',
#               Sentence(words=('महात्मा', 'गांधी', 'को', 'शासन', 'ब्रिटिश'), tags=('Mahatma', 'Gandhi', 'To', 'Governance', 'Thebritish'))),
#              ('b123',
#               Sentence(words=('महात्मा', 'गांधी', 'ब्रिटिश', 'को', 'शासन'), tags=('Mahatma', 'Gandhi', 'Thebritish', 'To', 'Governance'))),
#              ('b124',
#               Sentence(words=('महात्मा', 'गांधी', 'ब्रिटिश', 'शासन', 'को'), tags=('Mahatma', 'Gandhi', 'Thebritish', 'Governance', 'To'))),
#              ('b125',
#               Sentence(words=('महात्मा', 'गांधी', 'शासन', 'को', 'ब्रिटिश'), tags=('Mahatma', 'Gandhi', 'Governance', 'To', 'Thebritish'))),
#              ('b126',
#               Sentence(words=('महात्मा', 'गांधी', 'शासन', 'ब्रिटिश', 'को'), tags=('Mahatma', 'Gandhi', 'Governance', 'Thebritish', 'To'))),
#              ('b127',
#               Sentence(words=('महात्मा', 'को', 'गांधी', 'ब्रिटिश', 'शासन'), tags=('Mahatma', 'To', 'Gandhi', 'Thebritish', 'Governance'))),
#              ('b128',
#               Sentence(words=('महात्मा', 'को', 'गांधी', 'शासन', 'ब्रिटिश'), tags=('Mahatma', 'To', 'Gandhi', 'Governance', 'Thebritish'))),
#              ('b129',
#               Sentence(words=('महात्मा', 'को', 'ब्रिटिश', 'गांधी', 'शासन'), tags=('Mahatma', 'To', 'Thebritish', 'Gandhi', 'Governance'))),
#              ('b130',
#               Sentence(words=('महात्मा', 'को', 'ब्रिटिश', 'शासन', 'गांधी'), tags=('Mahatma', 'To', 'Thebritish', 'Governance', 'Gandhi'))),
#              ('b131',
#               Sentence(words=('महात्मा', 'को', 'शासन', 'गांधी', 'ब्रिटिश'), tags=('Mahatma', 'To', 'Governance', 'Gandhi', 'Thebritish'))),
#              ('b132',
#               Sentence(words=('महात्मा', 'को', 'शासन', 'ब्रिटिश', 'गांधी'), tags=('Mahatma', 'To', 'Governance', 'Thebritish', 'Gandhi'))),
#              ('b133',
#               Sentence(words=('महात्मा', 'ब्रिटिश', 'गांधी', 'को', 'शासन'), tags=('Mahatma', 'Thebritish', 'Gandhi', 'To', 'Governance'))),
#              ('b134',
#               Sentence(words=('महात्मा', 'ब्रिटिश', 'गांधी', 'शासन', 'को'), tags=('Mahatma', 'Thebritish', 'Gandhi', 'Governance', 'To'))),
#              ('b135',
#               Sentence(words=('महात्मा', 'ब्रिटिश', 'को', 'गांधी', 'शासन'), tags=('Mahatma', 'Thebritish', 'To', 'Gandhi', 'Governance'))),
#              ('b136',
#               Sentence(words=('महात्मा', 'ब्रिटिश', 'को', 'शासन', 'गांधी'), tags=('Mahatma', 'Thebritish', 'To', 'Governance', 'Gandhi'))),
#              ('b137',
#               Sentence(words=('महात्मा', 'ब्रिटिश', 'शासन', 'गांधी', 'को'), tags=('Mahatma', 'Thebritish', 'Governance', 'Gandhi', 'To'))),
#              ('b138',
#               Sentence(words=('महात्मा', 'ब्रिटिश', 'शासन', 'को', 'गांधी'), tags=('Mahatma', 'Thebritish', 'Governance', 'To', 'Gandhi'))),
#              ('b139',
#               Sentence(words=('महात्मा', 'शासन', 'गांधी', 'को', 'ब्रिटिश'), tags=('Mahatma', 'Governance', 'Gandhi', 'To', 'Thebritish'))),
#              ('b140',
#               Sentence(words=('महात्मा', 'शासन', 'गांधी', 'ब्रिटिश', 'को'), tags=('Mahatma', 'Governance', 'Gandhi', 'Thebritish', 'To'))),
#              ('b141',
#               Sentence(words=('महात्मा', 'शासन', 'को', 'गांधी', 'ब्रिटिश'), tags=('Mahatma', 'Governance', 'To', 'Gandhi', 'Thebritish'))),
#              ('b142',
#               Sentence(words=('महात्मा', 'शासन', 'को', 'ब्रिटिश', 'गांधी'), tags=('Mahatma', 'Governance', 'To', 'Thebritish', 'Gandhi'))),
#              ('b143',
#               Sentence(words=('महात्मा', 'शासन', 'ब्रिटिश', 'गांधी', 'को'), tags=('Mahatma', 'Governance', 'Thebritish', 'Gandhi', 'To'))),
#              ('b144',
#               Sentence(words=('महात्मा', 'शासन', 'ब्रिटिश', 'को', 'गांधी'), tags=('Mahatma', 'Governance', 'Thebritish', 'To', 'Gandhi'))),
#              ('b145',
#               Sentence(words=('गांधी', 'महात्मा', 'को', 'ब्रिटिश', 'शासन'), tags=('Gandhi', 'Mahatma', 'To', 'Thebritish', 'Governance'))),
#              ('b146',
#               Sentence(words=('गांधी', 'महात्मा', 'को', 'शासन', 'ब्रिटिश'), tags=('Gandhi', 'Mahatma', 'To', 'Governance', 'Thebritish'))),
#              ('b147',
#               Sentence(words=('गांधी', 'महात्मा', 'ब्रिटिश', 'को', 'शासन'), tags=('Gandhi', 'Mahatma', 'Thebritish', 'To', 'Governance'))),
#              ('b148',
#               Sentence(words=('गांधी', 'महात्मा', 'ब्रिटिश', 'शासन', 'को'), tags=('Gandhi', 'Mahatma', 'Thebritish', 'Governance', 'To'))),
#              ('b149',
#               Sentence(words=('गांधी', 'महात्मा', 'शासन', 'को', 'ब्रिटिश'), tags=('Gandhi', 'Mahatma', 'Governance', 'To', 'Thebritish'))),
#              ('b150',
#               Sentence(words=('गांधी', 'महात्मा', 'शासन', 'ब्रिटिश', 'को'), tags=('Gandhi', 'Mahatma', 'Governance', 'Thebritish', 'To'))),
#              ('b151',
#               Sentence(words=('गांधी', 'को', 'महात्मा', 'ब्रिटिश', 'शासन'), tags=('Gandhi', 'To', 'Mahatma', 'Thebritish', 'Governance'))),
#              ('b152',
#               Sentence(words=('गांधी', 'को', 'महात्मा', 'शासन', 'ब्रिटिश'), tags=('Gandhi', 'To', 'Mahatma', 'Governance', 'Thebritish'))),
#              ('b153',
#               Sentence(words=('गांधी', 'को', 'ब्रिटिश', 'महात्मा', 'शासन'), tags=('Gandhi', 'To', 'Thebritish', 'Mahatma', 'Governance'))),
#              ('b154',
#               Sentence(words=('गांधी', 'को', 'ब्रिटिश', 'शासन', 'महात्मा'), tags=('Gandhi', 'To', 'Thebritish', 'Governance', 'Mahatma'))),
#              ('b155',
#               Sentence(words=('गांधी', 'को', 'शासन', 'महात्मा', 'ब्रिटिश'), tags=('Gandhi', 'To', 'Governance', 'Mahatma', 'Thebritish'))),
#              ('b156',
#               Sentence(words=('गांधी', 'को', 'शासन', 'ब्रिटिश', 'महात्मा'), tags=('Gandhi', 'To', 'Governance', 'Thebritish', 'Mahatma'))),
#              ('b157',
#               Sentence(words=('गांधी', 'ब्रिटिश', 'महात्मा', 'को', 'शासन'), tags=('Gandhi', 'Thebritish', 'Mahatma', 'To', 'Governance'))),
#              ('b158',
#               Sentence(words=('गांधी', 'ब्रिटिश', 'महात्मा', 'शासन', 'को'), tags=('Gandhi', 'Thebritish', 'Mahatma', 'Governance', 'To'))),
#              ('b159',
#               Sentence(words=('गांधी', 'ब्रिटिश', 'को', 'महात्मा', 'शासन'), tags=('Gandhi', 'Thebritish', 'To', 'Mahatma', 'Governance'))),
#              ('b160',
#               Sentence(words=('गांधी', 'ब्रिटिश', 'को', 'शासन', 'महात्मा'), tags=('Gandhi', 'Thebritish', 'To', 'Governance', 'Mahatma'))),
#              ('b161',
#               Sentence(words=('गांधी', 'ब्रिटिश', 'शासन', 'महात्मा', 'को'), tags=('Gandhi', 'Thebritish', 'Governance', 'Mahatma', 'To'))),
#              ('b162',
#               Sentence(words=('गांधी', 'ब्रिटिश', 'शासन', 'को', 'महात्मा'), tags=('Gandhi', 'Thebritish', 'Governance', 'To', 'Mahatma'))),
#              ('b163',
#               Sentence(words=('गांधी', 'शासन', 'महात्मा', 'को', 'ब्रिटिश'), tags=('Gandhi', 'Governance', 'Mahatma', 'To', 'Thebritish'))),
#              ('b164',
#               Sentence(words=('गांधी', 'शासन', 'महात्मा', 'ब्रिटिश', 'को'), tags=('Gandhi', 'Governance', 'Mahatma', 'Thebritish', 'To'))),
#              ('b165',
#               Sentence(words=('गांधी', 'शासन', 'को', 'महात्मा', 'ब्रिटिश'), tags=('Gandhi', 'Governance', 'To', 'Mahatma', 'Thebritish'))),
#              ('b166',
#               Sentence(words=('गांधी', 'शासन', 'को', 'ब्रिटिश', 'महात्मा'), tags=('Gandhi', 'Governance', 'To', 'Thebritish', 'Mahatma'))),
#              ('b167',
#               Sentence(words=('गांधी', 'शासन', 'ब्रिटिश', 'महात्मा', 'को'), tags=('Gandhi', 'Governance', 'Thebritish', 'Mahatma', 'To'))),
#              ('b168',
#               Sentence(words=('गांधी', 'शासन', 'ब्रिटिश', 'को', 'महात्मा'), tags=('Gandhi', 'Governance', 'Thebritish', 'To', 'Mahatma'))),
#              ('b169',
#               Sentence(words=('को', 'महात्मा', 'गांधी', 'ब्रिटिश', 'शासन'), tags=('To', 'Mahatma', 'Gandhi', 'Thebritish', 'Governance'))),
#              ('b170',
#               Sentence(words=('को', 'महात्मा', 'गांधी', 'शासन', 'ब्रिटिश'), tags=('To', 'Mahatma', 'Gandhi', 'Governance', 'Thebritish'))),
#              ('b171',
#               Sentence(words=('को', 'महात्मा', 'ब्रिटिश', 'गांधी', 'शासन'), tags=('To', 'Mahatma', 'Thebritish', 'Gandhi', 'Governance'))),
#              ('b172',
#               Sentence(words=('को', 'महात्मा', 'ब्रिटिश', 'शासन', 'गांधी'), tags=('To', 'Mahatma', 'Thebritish', 'Governance', 'Gandhi'))),
#              ('b173',
#               Sentence(words=('को', 'महात्मा', 'शासन', 'गांधी', 'ब्रिटिश'), tags=('To', 'Mahatma', 'Governance', 'Gandhi', 'Thebritish'))),
#              ('b174',
#               Sentence(words=('को', 'महात्मा', 'शासन', 'ब्रिटिश', 'गांधी'), tags=('To', 'Mahatma', 'Governance', 'Thebritish', 'Gandhi'))),
#              ('b175',
#               Sentence(words=('को', 'गांधी', 'महात्मा', 'ब्रिटिश', 'शासन'), tags=('To', 'Gandhi', 'Mahatma', 'Thebritish', 'Governance'))),
#              ('b176',
#               Sentence(words=('को', 'गांधी', 'महात्मा', 'शासन', 'ब्रिटिश'), tags=('To', 'Gandhi', 'Mahatma', 'Governance', 'Thebritish'))),
#              ('b177',
#               Sentence(words=('को', 'गांधी', 'ब्रिटिश', 'महात्मा', 'शासन'), tags=('To', 'Gandhi', 'Thebritish', 'Mahatma', 'Governance'))),
#              ('b178',
#               Sentence(words=('को', 'गांधी', 'ब्रिटिश', 'शासन', 'महात्मा'), tags=('To', 'Gandhi', 'Thebritish', 'Governance', 'Mahatma'))),
#              ('b179',
#               Sentence(words=('को', 'गांधी', 'शासन', 'महात्मा', 'ब्रिटिश'), tags=('To', 'Gandhi', 'Governance', 'Mahatma', 'Thebritish'))),
#              ('b180',
#               Sentence(words=('को', 'गांधी', 'शासन', 'ब्रिटिश', 'महात्मा'), tags=('To', 'Gandhi', 'Governance', 'Thebritish', 'Mahatma'))),
#              ('b181',
#               Sentence(words=('को', 'ब्रिटिश', 'महात्मा', 'गांधी', 'शासन'), tags=('To', 'Thebritish', 'Mahatma', 'Gandhi', 'Governance'))),
#              ('b182',
#               Sentence(words=('को', 'ब्रिटिश', 'महात्मा', 'शासन', 'गांधी'), tags=('To', 'Thebritish', 'Mahatma', 'Governance', 'Gandhi'))),
#              ('b183',
#               Sentence(words=('को', 'ब्रिटिश', 'गांधी', 'महात्मा', 'शासन'), tags=('To', 'Thebritish', 'Gandhi', 'Mahatma', 'Governance'))),
#              ('b184',
#               Sentence(words=('को', 'ब्रिटिश', 'गांधी', 'शासन', 'महात्मा'), tags=('To', 'Thebritish', 'Gandhi', 'Governance', 'Mahatma'))),
#              ('b185',
#               Sentence(words=('को', 'ब्रिटिश', 'शासन', 'महात्मा', 'गांधी'), tags=('To', 'Thebritish', 'Governance', 'Mahatma', 'Gandhi'))),
#              ('b186',
#               Sentence(words=('को', 'ब्रिटिश', 'शासन', 'गांधी', 'महात्मा'), tags=('To', 'Thebritish', 'Governance', 'Gandhi', 'Mahatma'))),
#              ('b187',
#               Sentence(words=('को', 'शासन', 'महात्मा', 'गांधी', 'ब्रिटिश'), tags=('To', 'Governance', 'Mahatma', 'Gandhi', 'Thebritish'))),
#              ('b188',
#               Sentence(words=('को', 'शासन', 'महात्मा', 'ब्रिटिश', 'गांधी'), tags=('To', 'Governance', 'Mahatma', 'Thebritish', 'Gandhi'))),
#              ('b189',
#               Sentence(words=('को', 'शासन', 'गांधी', 'महात्मा', 'ब्रिटिश'), tags=('To', 'Governance', 'Gandhi', 'Mahatma', 'Thebritish'))),
#              ('b190',
#               Sentence(words=('को', 'शासन', 'गांधी', 'ब्रिटिश', 'महात्मा'), tags=('To', 'Governance', 'Gandhi', 'Thebritish', 'Mahatma'))),
#              ('b191',
#               Sentence(words=('को', 'शासन', 'ब्रिटिश', 'महात्मा', 'गांधी'), tags=('To', 'Governance', 'Thebritish', 'Mahatma', 'Gandhi'))),
#              ('b192',
#               Sentence(words=('को', 'शासन', 'ब्रिटिश', 'गांधी', 'महात्मा'), tags=('To', 'Governance', 'Thebritish', 'Gandhi', 'Mahatma'))),
#              ('b193',
#               Sentence(words=('ब्रिटिश', 'महात्मा', 'गांधी', 'को', 'शासन'), tags=('Thebritish', 'Mahatma', 'Gandhi', 'To', 'Governance'))),
#              ('b194',
#               Sentence(words=('ब्रिटिश', 'महात्मा', 'गांधी', 'शासन', 'को'), tags=('Thebritish', 'Mahatma', 'Gandhi', 'Governance', 'To'))),
#              ('b195',
#               Sentence(words=('ब्रिटिश', 'महात्मा', 'को', 'गांधी', 'शासन'), tags=('Thebritish', 'Mahatma', 'To', 'Gandhi', 'Governance'))),
#              ('b196',
#               Sentence(words=('ब्रिटिश', 'महात्मा', 'को', 'शासन', 'गांधी'), tags=('Thebritish', 'Mahatma', 'To', 'Governance', 'Gandhi'))),
#              ('b197',
#               Sentence(words=('ब्रिटिश', 'महात्मा', 'शासन', 'गांधी', 'को'), tags=('Thebritish', 'Mahatma', 'Governance', 'Gandhi', 'To'))),
#              ('b198',
#               Sentence(words=('ब्रिटिश', 'महात्मा', 'शासन', 'को', 'गांधी'), tags=('Thebritish', 'Mahatma', 'Governance', 'To', 'Gandhi'))),
#              ('b199',
#               Sentence(words=('ब्रिटिश', 'गांधी', 'महात्मा', 'को', 'शासन'), tags=('Thebritish', 'Gandhi', 'Mahatma', 'To', 'Governance'))),
#              ('b200',
#               Sentence(words=('ब्रिटिश', 'गांधी', 'महात्मा', 'शासन', 'को'), tags=('Thebritish', 'Gandhi', 'Mahatma', 'Governance', 'To'))),
#              ('b201',
#               Sentence(words=('ब्रिटिश', 'गांधी', 'को', 'महात्मा', 'शासन'), tags=('Thebritish', 'Gandhi', 'To', 'Mahatma', 'Governance'))),
#              ('b202',
#               Sentence(words=('ब्रिटिश', 'गांधी', 'को', 'शासन', 'महात्मा'), tags=('Thebritish', 'Gandhi', 'To', 'Governance', 'Mahatma'))),
#              ('b203',
#               Sentence(words=('ब्रिटिश', 'गांधी', 'शासन', 'महात्मा', 'को'), tags=('Thebritish', 'Gandhi', 'Governance', 'Mahatma', 'To'))),
#              ('b204',
#               Sentence(words=('ब्रिटिश', 'गांधी', 'शासन', 'को', 'महात्मा'), tags=('Thebritish', 'Gandhi', 'Governance', 'To', 'Mahatma'))),
#              ('b205',
#               Sentence(words=('ब्रिटिश', 'को', 'महात्मा', 'गांधी', 'शासन'), tags=('Thebritish', 'To', 'Mahatma', 'Gandhi', 'Governance'))),
#              ('b206',
#               Sentence(words=('ब्रिटिश', 'को', 'महात्मा', 'शासन', 'गांधी'), tags=('Thebritish', 'To', 'Mahatma', 'Governance', 'Gandhi'))),
#              ('b207',
#               Sentence(words=('ब्रिटिश', 'को', 'गांधी', 'महात्मा', 'शासन'), tags=('Thebritish', 'To', 'Gandhi', 'Mahatma', 'Governance'))),
#              ('b208',
#               Sentence(words=('ब्रिटिश', 'को', 'गांधी', 'शासन', 'महात्मा'), tags=('Thebritish', 'To', 'Gandhi', 'Governance', 'Mahatma'))),
#              ('b209',
#               Sentence(words=('ब्रिटिश', 'को', 'शासन', 'महात्मा', 'गांधी'), tags=('Thebritish', 'To', 'Governance', 'Mahatma', 'Gandhi'))),
#              ('b210',
#               Sentence(words=('ब्रिटिश', 'को', 'शासन', 'गांधी', 'महात्मा'), tags=('Thebritish', 'To', 'Governance', 'Gandhi', 'Mahatma'))),
#              ('b211',
#               Sentence(words=('ब्रिटिश', 'शासन', 'महात्मा', 'गांधी', 'को'), tags=('Thebritish', 'Governance', 'Mahatma', 'Gandhi', 'To'))),
#              ('b212',
#               Sentence(words=('ब्रिटिश', 'शासन', 'महात्मा', 'को', 'गांधी'), tags=('Thebritish', 'Governance', 'Mahatma', 'To', 'Gandhi'))),
#              ('b213',
#               Sentence(words=('ब्रिटिश', 'शासन', 'गांधी', 'महात्मा', 'को'), tags=('Thebritish', 'Governance', 'Gandhi', 'Mahatma', 'To'))),
#              ('b214',
#               Sentence(words=('ब्रिटिश', 'शासन', 'गांधी', 'को', 'महात्मा'), tags=('Thebritish', 'Governance', 'Gandhi', 'To', 'Mahatma'))),
#              ('b215',
#               Sentence(words=('ब्रिटिश', 'शासन', 'को', 'महात्मा', 'गांधी'), tags=('Thebritish', 'Governance', 'To', 'Mahatma', 'Gandhi'))),
#              ('b216',
#               Sentence(words=('ब्रिटिश', 'शासन', 'को', 'गांधी', 'महात्मा'), tags=('Thebritish', 'Governance', 'To', 'Gandhi', 'Mahatma'))),
#              ('b217',
#               Sentence(words=('शासन', 'महात्मा', 'गांधी', 'को', 'ब्रिटिश'), tags=('Governance', 'Mahatma', 'Gandhi', 'To', 'Thebritish'))),
#              ('b218',
#               Sentence(words=('शासन', 'महात्मा', 'गांधी', 'ब्रिटिश', 'को'), tags=('Governance', 'Mahatma', 'Gandhi', 'Thebritish', 'To'))),
#              ('b219',
#               Sentence(words=('शासन', 'महात्मा', 'को', 'गांधी', 'ब्रिटिश'), tags=('Governance', 'Mahatma', 'To', 'Gandhi', 'Thebritish'))),
#              ('b220',
#               Sentence(words=('शासन', 'महात्मा', 'को', 'ब्रिटिश', 'गांधी'), tags=('Governance', 'Mahatma', 'To', 'Thebritish', 'Gandhi'))),
#              ('b221',
#               Sentence(words=('शासन', 'महात्मा', 'ब्रिटिश', 'गांधी', 'को'), tags=('Governance', 'Mahatma', 'Thebritish', 'Gandhi', 'To'))),
#              ('b222',
#               Sentence(words=('शासन', 'महात्मा', 'ब्रिटिश', 'को', 'गांधी'), tags=('Governance', 'Mahatma', 'Thebritish', 'To', 'Gandhi'))),
#              ('b223',
#               Sentence(words=('शासन', 'गांधी', 'महात्मा', 'को', 'ब्रिटिश'), tags=('Governance', 'Gandhi', 'Mahatma', 'To', 'Thebritish'))),
#              ('b224',
#               Sentence(words=('शासन', 'गांधी', 'महात्मा', 'ब्रिटिश', 'को'), tags=('Governance', 'Gandhi', 'Mahatma', 'Thebritish', 'To'))),
#              ('b225',
#               Sentence(words=('शासन', 'गांधी', 'को', 'महात्मा', 'ब्रिटिश'), tags=('Governance', 'Gandhi', 'To', 'Mahatma', 'Thebritish'))),
#              ('b226',
#               Sentence(words=('शासन', 'गांधी', 'को', 'ब्रिटिश', 'महात्मा'), tags=('Governance', 'Gandhi', 'To', 'Thebritish', 'Mahatma'))),
#              ('b227',
#               Sentence(words=('शासन', 'गांधी', 'ब्रिटिश', 'महात्मा', 'को'), tags=('Governance', 'Gandhi', 'Thebritish', 'Mahatma', 'To'))),
#              ('b228',
#               Sentence(words=('शासन', 'गांधी', 'ब्रिटिश', 'को', 'महात्मा'), tags=('Governance', 'Gandhi', 'Thebritish', 'To', 'Mahatma'))),
#              ('b229',
#               Sentence(words=('शासन', 'को', 'महात्मा', 'गांधी', 'ब्रिटिश'), tags=('Governance', 'To', 'Mahatma', 'Gandhi', 'Thebritish'))),
#              ('b230',
#               Sentence(words=('शासन', 'को', 'महात्मा', 'ब्रिटिश', 'गांधी'), tags=('Governance', 'To', 'Mahatma', 'Thebritish', 'Gandhi'))),
#              ('b231',
#               Sentence(words=('शासन', 'को', 'गांधी', 'महात्मा', 'ब्रिटिश'), tags=('Governance', 'To', 'Gandhi', 'Mahatma', 'Thebritish'))),
#              ('b232',
#               Sentence(words=('शासन', 'को', 'गांधी', 'ब्रिटिश', 'महात्मा'), tags=('Governance', 'To', 'Gandhi', 'Thebritish', 'Mahatma'))),
#              ('b233',
#               Sentence(words=('शासन', 'को', 'ब्रिटिश', 'महात्मा', 'गांधी'), tags=('Governance', 'To', 'Thebritish', 'Mahatma', 'Gandhi'))),
#              ('b234',
#               Sentence(words=('शासन', 'को', 'ब्रिटिश', 'गांधी', 'महात्मा'), tags=('Governance', 'To', 'Thebritish', 'Gandhi', 'Mahatma'))),
#              ('b235',
#               Sentence(words=('शासन', 'ब्रिटिश', 'महात्मा', 'गांधी', 'को'), tags=('Governance', 'Thebritish', 'Mahatma', 'Gandhi', 'To'))),
#              ('b236',
#               Sentence(words=('शासन', 'ब्रिटिश', 'महात्मा', 'को', 'गांधी'), tags=('Governance', 'Thebritish', 'Mahatma', 'To', 'Gandhi'))),
#              ('b237',
#               Sentence(words=('शासन', 'ब्रिटिश', 'गांधी', 'महात्मा', 'को'), tags=('Governance', 'Thebritish', 'Gandhi', 'Mahatma', 'To'))),
#              ('b238',
#               Sentence(words=('शासन', 'ब्रिटिश', 'गांधी', 'को', 'महात्मा'), tags=('Governance', 'Thebritish', 'Gandhi', 'To', 'Mahatma'))),
#              ('b239',
#               Sentence(words=('शासन', 'ब्रिटिश', 'को', 'महात्मा', 'गांधी'), tags=('Governance', 'Thebritish', 'To', 'Mahatma', 'Gandhi')))])

# %%
class Dataset(namedtuple("_Dataset", "sentences keys vocab X tagset Y training_set testing_set N stream")):
    def __new__(cls, tagfile, datafile, train_test_split=0.8, seed=112890):
        tagset = read_tags(tagfile)
        
        keys = tuple(sentences.keys())
        wordset = frozenset(chain(*[s.words for s in sentences.values()]))
        word_sequences = tuple([sentences[k].words for k in keys])
        tag_sequences = tuple([sentences[k].tags for k in keys])
        N = sum(1 for _ in chain(*(s.words for s in sentences.values())))
        
        # split data into train/test sets
        _keys = list(keys)
        if seed is not None: random.seed(seed)
        random.shuffle(_keys)
        split = int(train_test_split * len(_keys))
        training_data = Subset(sentences, _keys[:split])
        testing_data = Subset(sentences, _keys[split:])
        stream = tuple(zip(chain(*word_sequences), chain(*tag_sequences)))
        return super().__new__(cls, dict(sentences), keys, wordset, word_sequences, tagset,
                               tag_sequences, training_data, testing_data, N, stream.__iter__)

    def __len__(self):
        return len(self.sentences)

    def __iter__(self):
        return iter(self.sentences.items())
    
    
class Subset(namedtuple("BaseSet", "sentences keys vocab X tagset Y N stream")):
    def __new__(cls, sentences, keys):
        word_sequences = tuple([sentences[k].words for k in keys])
        tag_sequences = tuple([sentences[k].tags for k in keys])
        wordset = frozenset(chain(*word_sequences))
        tagset = frozenset(chain(*tag_sequences))
        N = sum(1 for _ in chain(*(sentences[k].words for k in keys)))
        stream = tuple(zip(chain(*word_sequences), chain(*tag_sequences)))
        return super().__new__(cls, {k: sentences[k] for k in keys}, keys, wordset, word_sequences,
                               tagset, tag_sequences, N, stream.__iter__)

    def __len__(self):
        return len(self.sentences)

    def __iter__(self):
        return iter(self.sentences.items())

# %%
data = Dataset("Eng_Split.txt", "FinalTags.txt", train_test_split=0.8)

print("There are {} sentences in the corpus.".format(len(data)))
print("There are {} sentences in the training set.".format(len(data.training_set)))
print("There are {} sentences in the testing set.".format(len(data.testing_set)))

assert len(data) == len(data.training_set) + len(data.testing_set), \
       "The number of sentences in the training set + testing set should sum to the number of sentences in the corpus"
# Out:
# There are 252 sentences in the corpus.
# There are 201 sentences in the training set.
# There are 51 sentences in the testing set.

# %%
print("There are a total of {} samples of {} unique words in the corpus."
      .format(data.N, len(data.vocab)))
print("There are {} samples of {} unique words in the training set."
      .format(data.training_set.N, len(data.training_set.vocab)))
print("There are {} samples of {} unique words in the testing set."
      .format(data.testing_set.N, len(data.testing_set.vocab)))
print("There are {} words in the test set that are missing in the training set."
      .format(len(data.testing_set.vocab - data.training_set.vocab)))

assert data.N == data.training_set.N + data.testing_set.N, \
       "The number of training + test samples should sum to the total number of samples"
# Out:
# There are a total of 1346 samples of 119 unique words in the corpus.
# There are 1069 samples of 100 unique words in the training set.
# There are 277 samples of 40 unique words in the testing set.
# There are 19 words in the test set that are missing in the training set.

# %% [markdown]
# Let's look at an example POS tagging:

# %%
key = 'b10'
print("Sentence: {}".format(key))
print("words:\n\t{!s}".format(data.sentences[key].words))
print("tags:\n\t{!s}".format(data.sentences[key].tags))
# Out:
# Sentence: b10
# words:
# 	('अंतरिक्ष', 'बगीचे', 'में', 'त', 'के')
# tags:
# 	('Space', 'Thegarden', 'In', 'T', 'Of')

# %% [markdown]
# This is how easy it is, now, to access words and associated tags, using the vocabulary of Machine Learning: `X` is the independent variable, and `Y` the dependent variable!

# %%
# accessing words with Dataset.X and tags with Dataset.Y 
for i in range(1):    
    print("Sentence {}:".format(i + 1), data.X[i])
    print()
    print("Labels {}:".format(i + 1), data.Y[i])
    print()
# Out:
# Sentence 1: ('एक', 'गमले', 'में', 'छोटे', 'पीले', 'संतरे', 'तो', 'दूसरे', 'में', 'एक', 'सेब', 'और', 'तीसरे', 'में', 'एक', 'नीबू', 'लटका', 'था')
#
# Labels 1: ('One', 'flowerpot', 'In', 'Small', 'Yellow', 'Oranges', 'so', 'Others', 'In', 'One', 'Apple', 'And', 'Third', 'In', 'One', 'lemon', 'Hang', 'Was')

# %% [markdown]
# Use `Dataset.stream()` to enumerate (word, tag) samples for the entire corpus. Let's enumerate the first 4:

# %%
print("\nStream (word, tag) pairs:\n")
for i, pair in enumerate(data.stream()):
    print("\t", pair)
    if i > 3: break
# Out:
# Stream (word, tag) pairs:
#
# 	 ('एक', 'One')
# 	 ('गमले', 'flowerpot')
# 	 ('में', 'In')
# 	 ('छोटे', 'Small')
# 	 ('पीले', 'Yellow')

# %% [markdown]
# These are all words and tags in our **training set**. Let's uncover the first 4:

# %%
words = [word for i, (word, tag) in enumerate(data.training_set.stream())]
tags = [tag for i, (word, tag) in enumerate(data.training_set.stream())]
words[0:4], tags[0:4]
# Out:
# (['बगीचे', 'में', 'अंतरिक्ष', 'त'], ['Thegarden', 'In', 'Space', 'T'])

# %% [markdown]
# # POS Tagger using BOW Model
#
# Let's create a dictionary of word + tag pairs where the values are just counts. Note that some words may be associated with different POS tags, in which case they will produce *distinct* pairs:

# %%
def pair_counts(tags, words):
    d = defaultdict(lambda: defaultdict(int))
    for tag, word in zip(tags, words):
        d[tag][word] += 1
    return d
        
word_counts = pair_counts(words, tags)

# %% [markdown]
# Let's produce a dictionary where words (keys) are associated with their ***most frequent*** POS tag:

# %%
mfc_table = dict((word, max(tags.keys(), key=lambda key: tags[key])) for word, tags in word_counts.items())

# %%
i = 0
for key, value in mfc_table.items():
    print(key, value)
    i += 1
    if i > 3: break
# Out:
# बगीचे Thegarden
# में In
# अंतरिक्ष Space
# त T

# %% [markdown]
# Python `namedtuple` supports a type of container-like dictionary that, like dictionaries, contains keys that are hashed to particular values. But it supports *both* access from key values as well as *iteration*, the functionality that dictionaries lack.
#
# Let's write a class that takes in a table in its constructor and adds `<MISSING>` POS tags if the word is missing from the training set (possible that a word is in the test set but missing from the training set). It also has a `viterbi` method that takes in the table and builds a sequence of states that we will use in our Hidden Markov Model.

# %%
FakeState = namedtuple('FakeState', 'name')

class MFCTagger:
    missing = FakeState(name = '<MISSING>')
    
    def __init__(self, table):
        self.table = defaultdict(lambda: MFCTagger.missing)
        self.table.update({word: FakeState(name=tag) for word, tag in table.items()})
        
    def viterbi(self, seq):
        """This method simplifies predictions by matching the Pomegranate viterbi() interface"""
        return 0., list(enumerate(["<start>"] + [self.table[w] for w in seq] + ["<end>"]))

# %%
mfc_model = MFCTagger(mfc_table)

# %% [markdown]
# So essentially we built a table that associates words with their most frequent POS tag. This is a simplistic **bag of words** (BOW) model. Let's see, given a sentence, if we *guess the hidden states* (POS tags) right!

# %%
def replace_unknown(sequence):
    return [w if w in data.training_set.vocab else 'nan' for w in sequence]

def simplify_decoding(X, model):    
    _, state_path = model.viterbi(replace_unknown(X))
    return [state[1].name for state in state_path[1:-1]]

# %%
for key in data.testing_set.keys[:3]:
    print("Sentence Key: {}\n".format(key))
    print("Sentence: {}\n".format(data.sentences[key].words))
    print("Predicted labels:\n-----------------")
    print(simplify_decoding(data.sentences[key].words, mfc_model))
    print()
    print("Actual labels:\n--------------")
    print(data.sentences[key].tags)
    print("\n")
# Out:
# Sentence Key: b140
#
# Sentence: ('महात्मा', 'शासन', 'गांधी', 'ब्रिटिश', 'को')
#
# Predicted labels:
# -----------------
# ['Mahatma', 'Governance', 'Gandhi', 'Thebritish', 'To']
#
# Actual labels:
# --------------
# ('Mahatma', 'Governance', 'Gandhi', 'Thebritish', 'To')
#
#
# Sentence Key: b34
#
# Sentence: ('के', 'बगीचे', 'में', 'त', 'अंतरिक्ष')
#
# Predicted labels:
# -----------------
# ['Of', 'Thegarden', 'In', 'T', 'Space']
#
# Actual labels:
# --------------
# ('Of', 'Thegarden', 'In', 'T', 'Space')
#
#
# Sentence Key: b96
#
# Sentence: ('में', 'त', 'बगीचे', 'के', 'अंतरिक्ष')
#
# Predicted labels:
# -----------------
# ['In', 'T', 'Thegarden', 'Of', 'Space']
#
# Actual labels:
# --------------
# ('In', 'T', 'Thegarden', 'Of', 'Space')

# %% [markdown]
# Pretty good! Let's evaluate the accuracy of our most-frequent-tag tagger:

# %%
def accuracy(X, Y, model):
    
    correct = total_predictions = 0
    for observations, actual_tags in zip(X, Y):
        
        # The model.viterbi call in simplify_decoding will return None if the HMM
        # raises an error (for example, if a test sentence contains a word that
        # is out of vocabulary for the training set). Any exception counts the
        # full sentence as an error (which makes this a conservative estimate).
        try:
            most_likely_tags = simplify_decoding(observations, model)
            correct += sum(p == t for p, t in zip(most_likely_tags, actual_tags))
        except:
            pass
        total_predictions += len(observations)
    return correct / total_predictions

# %%
mfc_training_acc = accuracy(data.training_set.X, data.training_set.Y, mfc_model)
print("training accuracy mfc_model: {:.2f}%".format(100 * mfc_training_acc))

mfc_testing_acc = accuracy(data.testing_set.X, data.testing_set.Y, mfc_model)
print("testing accuracy mfc_model: {:.2f}%".format(100 * mfc_testing_acc))
# Out:
# training accuracy mfc_model: 100.00%
# testing accuracy mfc_model: 93.14%

# %% [markdown]
# # Hidden Markov Model
#
# Let's build a POS tagger using a Hidden Markov Model.
#
# First, let's see how many POS tags we have in our corpus, using the python `Counter` structure that we used last week to count instances.

# %%
def unigram_counts(sequences):
    return Counter(sequences)

tags = [tag for i, (word, tag) in enumerate(data.training_set.stream())]
tag_unigrams = unigram_counts(tags)
tag_unigrams
# Out:
# Counter({'Thegarden': 100,
#          'In': 105,
#          'Space': 101,
#          'T': 100,
#          'Of': 105,
#          'Governance': 89,
#          'To': 89,
#          'Mahatma': 89,
#          'Gandhi': 89,
#          'Thebritish': 89,
#          'Fine': 2,
#          'is': 5,
#          'his': 2,
#          'after': 1,
#          'day': 1,
#          'time': 1,
#          'grandfatherSir': 2,
#          'with': 3,
#          'Chess': 1,
#          'Plays': 2,
#          'evening': 1,
#          'Time': 1,
#          'sometimes': 3,
#          'dad': 3,
#          "father'ssister": 1,
#          'Mummy': 1,
#          'that': 3,
#          'Tennis': 1,
#          'Badminton': 1,
#          'or': 1,
#          'Football': 2,
#          'Was': 2,
#          'Iam': 1,
#          'Willask': 1,
#          'when': 1,
#          'them': 1,
#          'Their': 1,
#          'Only': 2,
#          'Tell': 1,
#          'sport': 1,
#          'From': 1,
#          'Green': 2,
#          'Gives': 1,
#          'so': 4,
#          'Alie': 1,
#          'Tocry': 1,
#          'Acting': 1,
#          'do': 1,
#          'Happened': 1,
#          'Say': 1,
#          'Hey': 1,
#          'this': 1,
#          'Theboy': 1,
#          'very': 1,
#          'fast': 1,
#          'Ho': 1,
#          'Gone': 1,
#          'Toeveryone': 1,
#          'Plenty': 1,
#          'fun': 1,
#          'Does': 1,
#          'Yes': 1,
#          'Number': 1,
#          'two': 1,
#          'His': 1,
#          'Speak': 1,
#          'me': 1,
#          'Seems': 1,
#          'Spaceship': 1,
#          'bemade': 1,
#          'Themoon': 1,
#          'On': 1,
#          'Lasted': 1,
#          'Hasgone': 1,
#          'between': 1,
#          'Grass': 2,
#          'was': 1,
#          'Him': 1,
#          'every': 1,
#          'condition': 1,
#          'Jita': 1,
#          'give': 1,
#          'Want': 1,
#          'Were': 1,
#          'All': 1,
#          'Laughs': 1,
#          'One': 3,
#          'flowerpot': 1,
#          'Small': 1,
#          'Yellow': 1,
#          'Oranges': 1,
#          'Others': 1,
#          'Apple': 1,
#          'And': 1,
#          'Third': 1,
#          'lemon': 1,
#          'Hang': 1})

# %% [markdown]
# We'll *slightly* modify the code above to get our POS bigrams, from *both* training and test subsets, to uncover which POS tags follow which other POS tags. So, instead of a simple list of POS tags, `Counter` will count *neighboring* POS tuples!

# %%
def bigram_counts(sequences):
    return Counter(sequences)

tags = [tag for i, (word, tag) in enumerate(data.stream())]
o = [(tags[i],tags[i+1]) for i in range(0,len(tags)-2,2)]
tag_bigrams = bigram_counts(o)
tag_bigrams
# Out:
# Counter({('One', 'flowerpot'): 1,
#          ('In', 'Small'): 1,
#          ('Yellow', 'Oranges'): 1,
#          ('so', 'Others'): 1,
#          ('In', 'One'): 1,
#          ('Apple', 'And'): 1,
#          ('Third', 'In'): 1,
#          ('One', 'lemon'): 1,
#          ('Hang', 'Was'): 1,
#          ('between', 'In'): 1,
#          ('Green', 'Grass'): 1,
#          ('Only', 'Grass'): 1,
#          ('was', 'evening'): 1,
#          ('Of', 'Time'): 1,
#          ('sometimes', 'dad'): 1,
#          ('sometimes', "father'ssister"): 1,
#          ('sometimes', 'Mummy'): 1,
#          ('Of', 'with'): 1,
#          ('that', 'Tennis'): 1,
#          ('Badminton', 'or'): 1,
#          ('Football', 'Plays'): 1,
#          ('Was', 'Toeveryone'): 1,
#          ('with', 'that'): 1,
#          ('Plenty', 'fun'): 1,
#          ('Does', 'TV'): 1,
#          ('On', 'Football'): 1,
#          ('Theplayers', 'To'): 1,
#          ('See', 'something'): 1,
#          ('bytheway', 'Only'): 1,
#          ('Feat', 'Todo'): 1,
#          ('Of', 'try'): 1,
#          ('Does', 'his'): 1,
#          ('after', 'day'): 1,
#          ('Of', 'time'): 1,
#          ('grandfatherSir', 'Of'): 1,
#          ('with', 'Chess'): 1,
#          ('Plays', 'Play'): 1,
#          ('time', 'grandfatherSir'): 1,
#          ('Fromhim', 'Say'): 1,
#          ('Look', 'if'): 1,
#          ('you', 'this'): 1,
#          ('Trick', 'Willyougo'): 1,
#          ('so', 'Iam'): 1,
#          ('Your', 'Thehorses'): 1,
#          ('To', 'Kill'): 1,
#          ('Give', 'grandfatherSir'): 1,
#          ('Him', 'every'): 1,
#          ('condition', 'In'): 1,
#          ('Jita', 'give'): 1,
#          ('Want', 'Were'): 1,
#          ('All', 'Laughs'): 1,
#          ('when', 'Space'): 1,
#          ('them', 'Their'): 1,
#          ('Only', 'Tell'): 1,
#          ('sport', 'From'): 1,
#          ('Green', 'Gives'): 1,
#          ('so', 'that'): 1,
#          ('Alie', 'Tocry'): 1,
#          ('Of', 'Acting'): 1,
#          ('do', 'Happened'): 1,
#          ('Say', 'Hey'): 1,
#          ('this', 'Theboy'): 1,
#          ('so', 'very'): 1,
#          ('fast', 'Ho'): 1,
#          ('Gone', 'is'): 1,
#          ('dad', 'Speak'): 1,
#          ('me', 'so'): 1,
#          ('Seems', 'is'): 1,
#          ('his', 'Football'): 1,
#          ('Spaceship', 'bemade'): 1,
#          ('Themoon', 'On'): 1,
#          ('Lasted', 'Hasgone'): 1,
#          ('is', 'Yes'): 1,
#          ('dad', 'Number'): 1,
#          ('two', 'His'): 1,
#          ('Iam', 'Willask'): 1,
#          ('Fine', 'is'): 2,
#          ('Space', 'Of'): 12,
#          ('Thegarden', 'In'): 12,
#          ('T', 'Space'): 24,
#          ('Of', 'Thegarden'): 12,
#          ('T', 'In'): 18,
#          ('In', 'Thegarden'): 18,
#          ('Of', 'In'): 10,
#          ('T', 'Thegarden'): 20,
#          ('In', 'Space'): 22,
#          ('Of', 'T'): 8,
#          ('Space', 'Thegarden'): 10,
#          ('Thegarden', 'Of'): 18,
#          ('In', 'Of'): 20,
#          ('T', 'Of'): 22,
#          ('Thegarden', 'T'): 10,
#          ('Space', 'In'): 8,
#          ('Thegarden', 'Space'): 20,
#          ('In', 'T'): 12,
#          ('Space', 'T'): 6,
#          ('Of', 'Space'): 18,
#          ('Mahatma', 'Gandhi'): 16,
#          ('To', 'Governance'): 20,
#          ('Thebritish', 'Mahatma'): 8,
#          ('Gandhi', 'Thebritish'): 20,
#          ('Thebritish', 'Governance'): 17,
#          ('To', 'Mahatma'): 10,
#          ('Gandhi', 'Governance'): 22,
#          ('To', 'Thebritish'): 18,
#          ('Governance', 'Thebritish'): 11,
#          ('To', 'Gandhi'): 11,
#          ('Mahatma', 'To'): 20,
#          ('Gandhi', 'Mahatma'): 11,
#          ('Thebritish', 'Gandhi'): 10,
#          ('Mahatma', 'Thebritish'): 22,
#          ('Thebritish', 'To'): 12,
#          ('Gandhi', 'To'): 17,
#          ('Governance', 'To'): 10,
#          ('Governance', 'Gandhi'): 8,
#          ('Mahatma', 'Governance'): 24,
#          ('Gandhi', 'Gandhi'): 1,
#          ('Governance', 'Mahatma'): 6})

# %% [markdown]
# What tags do our sentences *begin* with?

# %%
def starting_counts(sequences):
    return Counter(sequences)

tags = [tag for i, (word, tag) in enumerate(data.stream())]
starts_tag = [i[0] for i in data.Y]
tag_starts = starting_counts(starts_tag)
tag_starts
# Out:
# Counter({'One': 1,
#          'between': 1,
#          'evening': 1,
#          'Toeveryone': 1,
#          'TV': 1,
#          'his': 1,
#          'Play': 1,
#          'grandfatherSir': 1,
#          'All': 1,
#          'when': 1,
#          'dad': 1,
#          'Yes': 1,
#          'Iam': 1,
#          'Fine': 1,
#          'Space': 24,
#          'Of': 24,
#          'Thegarden': 24,
#          'In': 24,
#          'T': 24,
#          'Mahatma': 23,
#          'Gandhi': 24,
#          'To': 24,
#          'Thebritish': 24,
#          'Governance': 23})

# %% [markdown]
# What tags do our sentences *end* with?

# %%
def ending_counts(sequences):    
    return Counter(sequences)

end_tag = [i[len(i)-2] for i in data.Y]
tag_ends = ending_counts(end_tag)
tag_ends
# Out:
# Counter({'Hang': 1,
#          'Grass': 1,
#          'Plays': 1,
#          'fun': 1,
#          'try': 1,
#          'Chess': 1,
#          'Kill': 1,
#          'Want': 1,
#          'All': 1,
#          'Gone': 1,
#          'Hasgone': 1,
#          'two': 1,
#          'Iam': 1,
#          'Fine': 1,
#          'In': 24,
#          'T': 24,
#          'Thegarden': 24,
#          'Of': 24,
#          'Space': 24,
#          'Governance': 24,
#          'To': 24,
#          'Thebritish': 23,
#          'Gandhi': 23,
#          'Mahatma': 24})

# %%
def ending_counts(sequences):    
    return Counter(sequences)

end_tag = [i[len(i)-1] for i in data.Y]
tag_ends = ending_counts(end_tag)
tag_ends
# Out:
# Counter({'Was': 2,
#          'was': 1,
#          'Does': 2,
#          'Plays': 1,
#          'Give': 1,
#          'Were': 1,
#          'Laughs': 1,
#          'is': 3,
#          'His': 1,
#          'Willask': 1,
#          'T': 24,
#          'In': 24,
#          'Thegarden': 24,
#          'Of': 24,
#          'Space': 24,
#          'Thebritish': 24,
#          'Governance': 23,
#          'To': 24,
#          'Gandhi': 24,
#          'Mahatma': 23})

# %% [markdown]
# Not surprising that most end with a period `.`! Ideally, we should end with the previous-to-last tag!

# %%
end_tag = [i[len(i)-1] for i in data.Y]
tag_ends = ending_counts(end_tag)
tag_ends
# Out:
# Counter({'Was': 2,
#          'was': 1,
#          'Does': 2,
#          'Plays': 1,
#          'Give': 1,
#          'Were': 1,
#          'Laughs': 1,
#          'is': 3,
#          'His': 1,
#          'Willask': 1,
#          'T': 24,
#          'In': 24,
#          'Thegarden': 24,
#          'Of': 24,
#          'Space': 24,
#          'Thebritish': 24,
#          'Governance': 23,
#          'To': 24,
#          'Gandhi': 24,
#          'Mahatma': 23})

# %% [markdown]
# Let's create our Hidden Markov Model and peek into most popular words per POS tag.
#
# `tag_words_count` contains words associated to each POS tag, arranged by frequency so that we can eventually evaluate *emission* probabilities, which are probabilities of observable states (wrods) given hidden states (POS tags).

# %%
hmm_model = HiddenMarkovModel(name="base-hmm-tagger")

tags = [tag for i, (word, tag) in enumerate(data.stream())]
words = [word for i, (word, tag) in enumerate(data.stream())]

tags_count = unigram_counts(tags)
tag_words_count = pair_counts(tags, words)

starting_tag_list = [i[0] for i in data.Y]
#ending_tag_list = [i[-1] if len(i)==1 else i[-2] for i in data.Y]
#ending_tag_list = [i[-1] for i in data.Y]
ending_tag_list = [i[len(i)-1] for i in data.Y]

starting_tag_count = starting_counts(starting_tag_list) #the number of times a tag occured at the start
ending_tag_count = ending_counts(ending_tag_list)       #the number of times a tag occured at the end

tag_words_count
# Out:
# defaultdict(<function __main__.pair_counts.<locals>.<lambda>()>,
#             {'One': defaultdict(int, {'एक': 3}),
#              'flowerpot': defaultdict(int, {'गमले': 1}),
#              'In': defaultdict(int, {'में': 125}),
#              'Small': defaultdict(int, {'छोटे': 1}),
#              'Yellow': defaultdict(int, {'पीले': 1}),
#              'Oranges': defaultdict(int, {'संतरे': 1}),
#              'so': defaultdict(int, {'तो': 5}),
#              'Others': defaultdict(int, {'दूसरे': 1}),
#              'Apple': defaultdict(int, {'सेब': 1}),
#              'And': defaultdict(int, {'और': 1}),
#              'Third': defaultdict(int, {'तीसरे': 1}),
#              'lemon': defaultdict(int, {'नीबू': 1}),
#              'Hang': defaultdict(int, {'लटका': 1}),
#              'Was': defaultdict(int, {'था': 2}),
#              'between': defaultdict(int, {'बीच': 1}),
#              'Green': defaultdict(int, {'हरीहरी': 1, 'हरा': 1}),
#              'Grass': defaultdict(int, {'घास': 2}),
#              'Only': defaultdict(int, {'ही': 3}),
#              'was': defaultdict(int, {'थी': 1}),
#              'evening': defaultdict(int, {'शाम': 1}),
#              'Of': defaultdict(int, {'के': 124, 'की': 2}),
#              'Time': defaultdict(int, {'समय': 1}),
#              'sometimes': defaultdict(int, {'कभी': 3}),
#              'dad': defaultdict(int, {'पापा': 3}),
#              "father'ssister": defaultdict(int, {'बुआ': 1}),
#              'Mummy': defaultdict(int, {'मम्मी': 1}),
#              'with': defaultdict(int, {'साथ': 3}),
#              'that': defaultdict(int, {'वह': 3}),
#              'Tennis': defaultdict(int, {'टेनिस': 1}),
#              'Badminton': defaultdict(int, {'बैडमिंटन': 1}),
#              'or': defaultdict(int, {'या': 1}),
#              'Football': defaultdict(int, {'फुटबॉल': 3}),
#              'Plays': defaultdict(int, {'खेलता': 2}),
#              'Toeveryone': defaultdict(int, {'सबके': 1}),
#              'Plenty': defaultdict(int, {'खूब': 1}),
#              'fun': defaultdict(int, {'मस्ती': 1}),
#              'Does': defaultdict(int, {'करता': 2}),
#              'TV': defaultdict(int, {'टीवी': 1}),
#              'On': defaultdict(int, {'पर': 2}),
#              'Theplayers': defaultdict(int, {'खिलाड़ियों': 1}),
#              'To': defaultdict(int, {'को': 120}),
#              'See': defaultdict(int, {'देख': 1}),
#              'something': defaultdict(int, {'कुछकुछ': 1}),
#              'bytheway': defaultdict(int, {'वैसे': 1}),
#              'Feat': defaultdict(int, {'करतब': 1}),
#              'Todo': defaultdict(int, {'करने': 1}),
#              'try': defaultdict(int, {'कोशिश': 1}),
#              'his': defaultdict(int, {'उसके': 1, 'इसकी': 1}),
#              'after': defaultdict(int, {'बाद': 1}),
#              'day': defaultdict(int, {'दिन': 1}),
#              'time': defaultdict(int, {'वक्त': 2}),
#              'grandfatherSir': defaultdict(int, {'दादाजी': 3}),
#              'Chess': defaultdict(int, {'शतरंज': 1}),
#              'Play': defaultdict(int, {'खेलते': 1}),
#              'Fromhim': defaultdict(int, {'उससे': 1}),
#              'Say': defaultdict(int, {'कहते': 2}),
#              'Look': defaultdict(int, {'देखो': 1}),
#              'if': defaultdict(int, {'अगर': 1}),
#              'you': defaultdict(int, {'तुम': 1}),
#              'this': defaultdict(int, {'यह': 2}),
#              'Trick': defaultdict(int, {'चाल': 1}),
#              'Willyougo': defaultdict(int, {'चलोगे': 1}),
#              'Iam': defaultdict(int, {'मैं': 2}),
#              'Your': defaultdict(int, {'तुम्हारे': 1}),
#              'Thehorses': defaultdict(int, {'घोड़े': 1}),
#              'Kill': defaultdict(int, {'मार': 1}),
#              'Give': defaultdict(int, {'दूंगा': 1}),
#              'Him': defaultdict(int, {'उसे': 1}),
#              'every': defaultdict(int, {'हर': 1}),
#              'condition': defaultdict(int, {'हाल': 1}),
#              'Jita': defaultdict(int, {'जिता': 1}),
#              'give': defaultdict(int, {'देना': 1}),
#              'Want': defaultdict(int, {'चाहते': 1}),
#              'Were': defaultdict(int, {'थे': 1}),
#              'All': defaultdict(int, {'सब': 1}),
#              'Laughs': defaultdict(int, {'हंसते': 1}),
#              'when': defaultdict(int, {'जब': 1}),
#              'Space': defaultdict(int, {'अंतरिक्ष': 121}),
#              'them': defaultdict(int, {'उन्हें': 1}),
#              'Their': defaultdict(int, {'उनके': 1}),
#              'Tell': defaultdict(int, {'बताए': 1}),
#              'sport': defaultdict(int, {'खेल': 1}),
#              'From': defaultdict(int, {'से': 1}),
#              'Gives': defaultdict(int, {'देता': 1}),
#              'Alie': defaultdict(int, {'झूठमूठ': 1}),
#              'Tocry': defaultdict(int, {'रोने': 1}),
#              'Acting': defaultdict(int, {'एक्टिंग': 1}),
#              'do': defaultdict(int, {'करते': 1}),
#              'Happened': defaultdict(int, {'हुए': 1}),
#              'Hey': defaultdict(int, {'अरे': 1}),
#              'Theboy': defaultdict(int, {'लड़का': 1}),
#              'very': defaultdict(int, {'बहुत': 1}),
#              'fast': defaultdict(int, {'तेज': 1}),
#              'Ho': defaultdict(int, {'हो': 1}),
#              'Gone': defaultdict(int, {'गया': 1}),
#              'is': defaultdict(int, {'है': 5}),
#              'Speak': defaultdict(int, {'बोले': 1}),
#              'me': defaultdict(int, {'मुझे': 1}),
#              'Seems': defaultdict(int, {'लगता': 1}),
#              'Spaceship': defaultdict(int, {'स्पेसशिप': 1}),
#              'bemade': defaultdict(int, {'बनकर': 1}),
#              'Themoon': defaultdict(int, {'चांद': 1}),
#              'Lasted': defaultdict(int, {'चली': 1}),
#              'Hasgone': defaultdict(int, {'गई': 1}),
#              'Yes': defaultdict(int, {'हां': 1}),
#              'Number': defaultdict(int, {'नंबर': 1}),
#              'two': defaultdict(int, {'दो': 1}),
#              'His': defaultdict(int, {'उसका': 1}),
#              'Willask': defaultdict(int, {'पूछूंगा': 1}),
#              'Fine': defaultdict(int, {'ठीक': 2}),
#              'Thegarden': defaultdict(int, {'बगीचे': 120}),
#              'T': defaultdict(int, {'त': 120}),
#              'Mahatma': defaultdict(int, {'महात्मा': 118}),
#              'Gandhi': defaultdict(int, {'गांधी': 118}),
#              'Governance': defaultdict(int, {'शासन': 118}),
#              'Thebritish': defaultdict(int, {'ब्रिटिश': 118})})

# %%
ending_tag_list
# Out:
# ['Was',
#  'was',
#  'Was',
#  'Does',
#  'Does',
#  'Plays',
#  'Give',
#  'Were',
#  'Laughs',
#  'is',
#  'is',
#  'His',
#  'Willask',
#  'is',
#  'T',
#  'In',
#  'T',
#  'Thegarden',
#  'In',
#  'Thegarden',
#  'T',
#  'In',
#  'T',
#  'Of',
#  'In',
#  'Of',
#  'T',
#  'Thegarden',
#  'T',
#  'Of',
#  'Thegarden',
#  'Of',
#  'In',
#  'Thegarden',
#  'In',
#  'Of',
#  'Thegarden',
#  'Of',
#  'T',
#  'In',
#  'T',
#  'Thegarden',
#  'In',
#  'Thegarden',
#  'T',
#  'In',
#  'T',
#  'Space',
#  'In',
#  'Space',
#  'T',
#  'Thegarden',
#  'T',
#  'Space',
#  'Thegarden',
#  'Space',
#  'In',
#  'Thegarden',
#  'In',
#  'Space',
#  'Thegarden',
#  'Space',
#  'T',
#  'In',
#  'T',
#  'Of',
#  'In',
#  'Of',
#  'T',
#  'In',
#  'T',
#  'Space',
#  'In',
#  'Space',
#  'T',
#  'Of',
#  'T',
#  'Space',
#  'Of',
#  'Space',
#  'In',
#  'Of',
#  'In',
#  'Space',
#  'Of',
#  'Space',
#  'T',
#  'Thegarden',
#  'T',
#  'Of',
#  'Thegarden',
#  'Of',
#  'T',
#  'Thegarden',
#  'T',
#  'Space',
#  'Thegarden',
#  'Space',
#  'T',
#  'Of',
#  'T',
#  'Space',
#  'Of',
#  'Space',
#  'Thegarden',
#  'Of',
#  'Thegarden',
#  'Space',
#  'Of',
#  'Space',
#  'In',
#  'Thegarden',
#  'In',
#  'Of',
#  'Thegarden',
#  'Of',
#  'In',
#  'Thegarden',
#  'In',
#  'Space',
#  'Thegarden',
#  'Space',
#  'In',
#  'Of',
#  'In',
#  'Space',
#  'Of',
#  'Space',
#  'Thegarden',
#  'Of',
#  'Thegarden',
#  'Space',
#  'Of',
#  'Space',
#  'Thebritish',
#  'Governance',
#  'To',
#  'Thebritish',
#  'To',
#  'Governance',
#  'Thebritish',
#  'Governance',
#  'Gandhi',
#  'Thebritish',
#  'Gandhi',
#  'Governance',
#  'To',
#  'Governance',
#  'Gandhi',
#  'To',
#  'Gandhi',
#  'Thebritish',
#  'To',
#  'Thebritish',
#  'Gandhi',
#  'To',
#  'Gandhi',
#  'Governance',
#  'Thebritish',
#  'Governance',
#  'To',
#  'Thebritish',
#  'To',
#  'Governance',
#  'Thebritish',
#  'Governance',
#  'Mahatma',
#  'Thebritish',
#  'Mahatma',
#  'Governance',
#  'To',
#  'Governance',
#  'Mahatma',
#  'To',
#  'Mahatma',
#  'Thebritish',
#  'To',
#  'Thebritish',
#  'Mahatma',
#  'To',
#  'Mahatma',
#  'Governance',
#  'Thebritish',
#  'Governance',
#  'Gandhi',
#  'Thebritish',
#  'Gandhi',
#  'Governance',
#  'Thebritish',
#  'Governance',
#  'Mahatma',
#  'Thebritish',
#  'Mahatma',
#  'Governance',
#  'Gandhi',
#  'Governance',
#  'Mahatma',
#  'Gandhi',
#  'Mahatma',
#  'Thebritish',
#  'Gandhi',
#  'Thebritish',
#  'Mahatma',
#  'Gandhi',
#  'Mahatma',
#  'Governance',
#  'To',
#  'Governance',
#  'Gandhi',
#  'To',
#  'Gandhi',
#  'Governance',
#  'To',
#  'Governance',
#  'Mahatma',
#  'To',
#  'Mahatma',
#  'Governance',
#  'Gandhi',
#  'Governance',
#  'Mahatma',
#  'Gandhi',
#  'Mahatma',
#  'To',
#  'Gandhi',
#  'To',
#  'Mahatma',
#  'Gandhi',
#  'Mahatma',
#  'Thebritish',
#  'To',
#  'Thebritish',
#  'Gandhi',
#  'To',
#  'Gandhi',
#  'Thebritish',
#  'To',
#  'Thebritish',
#  'Mahatma',
#  'To',
#  'Mahatma',
#  'Thebritish',
#  'Gandhi',
#  'Thebritish',
#  'Mahatma',
#  'Gandhi',
#  'Mahatma',
#  'To',
#  'Gandhi',
#  'To',
#  'Mahatma',
#  'Gandhi']

# %% [markdown]
# Let's convert word frequencies by POS tag to probabilities by dividing by the total number of words per POS tag, yielding the `distribution` of words.
#
# We'll define HMM emission probabilities using that `distribution`.

# %%
to_pass_states = []
for tag, words_dict in tag_words_count.items():
    total = float(sum(words_dict.values()))
    distribution = {word: count/total for word, count in words_dict.items()}
    tag_emissions = DiscreteDistribution(distribution)
    tag_state = State(tag_emissions, name=tag)
    to_pass_states.append(tag_state)

# %%
distribution
# Out:
# {'ब्रिटिश': 1.0}

# %% [markdown]
# `to_pass_states` yields the probability distribution of words per POS tag:

# %%
to_pass_states
# Out:
# [{
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u090f\u0915" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "One",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0917\u092e\u0932\u0947" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "flowerpot",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u092e\u0947\u0902" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "In",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u091b\u094b\u091f\u0947" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Small",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u092a\u0940\u0932\u0947" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Yellow",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0938\u0902\u0924\u0930\u0947" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Oranges",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0924\u094b" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "so",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0926\u0942\u0938\u0930\u0947" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Others",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0938\u0947\u092c" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Apple",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0914\u0930" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "And",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0924\u0940\u0938\u0930\u0947" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Third",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0928\u0940\u092c\u0942" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "lemon",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0932\u091f\u0915\u093e" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Hang",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0925\u093e" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Was",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u092c\u0940\u091a" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "between",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0939\u0930\u0940\u0939\u0930\u0940" : 0.5,
#                  "\u0939\u0930\u093e" : 0.5
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Green",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0918\u093e\u0938" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Grass",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0939\u0940" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Only",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0925\u0940" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "was",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0936\u093e\u092e" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "evening",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0915\u0947" : 0.9841269841269841,
#                  "\u0915\u0940" : 0.015873015873015872
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Of",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0938\u092e\u092f" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Time",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0915\u092d\u0940" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "sometimes",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u092a\u093e\u092a\u093e" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "dad",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u092c\u0941\u0906" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "father'ssister",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u092e\u092e\u094d\u092e\u0940" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Mummy",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0938\u093e\u0925" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "with",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0935\u0939" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "that",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u091f\u0947\u0928\u093f\u0938" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Tennis",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u092c\u0948\u0921\u092e\u093f\u0902\u091f\u0928" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Badminton",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u092f\u093e" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "or",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u092b\u0941\u091f\u092c\u0949\u0932" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Football",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0916\u0947\u0932\u0924\u093e" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Plays",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0938\u092c\u0915\u0947" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Toeveryone",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0916\u0942\u092c" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Plenty",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u092e\u0938\u094d\u0924\u0940" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "fun",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0915\u0930\u0924\u093e" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Does",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u091f\u0940\u0935\u0940" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "TV",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u092a\u0930" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "On",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0916\u093f\u0932\u093e\u095c\u093f\u092f\u094b\u0902" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Theplayers",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0915\u094b" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "To",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0926\u0947\u0916" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "See",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0915\u0941\u091b\u0915\u0941\u091b" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "something",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0935\u0948\u0938\u0947" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "bytheway",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0915\u0930\u0924\u092c" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Feat",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0915\u0930\u0928\u0947" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Todo",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0915\u094b\u0936\u093f\u0936" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "try",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0909\u0938\u0915\u0947" : 0.5,
#                  "\u0907\u0938\u0915\u0940" : 0.5
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "his",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u092c\u093e\u0926" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "after",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0926\u093f\u0928" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "day",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0935\u0915\u094d\u0924" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "time",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0926\u093e\u0926\u093e\u091c\u0940" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "grandfatherSir",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0936\u0924\u0930\u0902\u091c" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Chess",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0916\u0947\u0932\u0924\u0947" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Play",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0909\u0938\u0938\u0947" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Fromhim",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0915\u0939\u0924\u0947" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Say",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0926\u0947\u0916\u094b" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Look",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0905\u0917\u0930" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "if",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0924\u0941\u092e" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "you",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u092f\u0939" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "this",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u091a\u093e\u0932" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Trick",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u091a\u0932\u094b\u0917\u0947" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Willyougo",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u092e\u0948\u0902" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Iam",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0924\u0941\u092e\u094d\u0939\u093e\u0930\u0947" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Your",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0918\u094b\u095c\u0947" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Thehorses",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u092e\u093e\u0930" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Kill",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0926\u0942\u0902\u0917\u093e" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Give",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0909\u0938\u0947" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Him",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0939\u0930" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "every",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0939\u093e\u0932" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "condition",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u091c\u093f\u0924\u093e" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Jita",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0926\u0947\u0928\u093e" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "give",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u091a\u093e\u0939\u0924\u0947" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Want",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0925\u0947" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Were",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0938\u092c" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "All",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0939\u0902\u0938\u0924\u0947" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Laughs",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u091c\u092c" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "when",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0905\u0902\u0924\u0930\u093f\u0915\u094d\u0937" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Space",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0909\u0928\u094d\u0939\u0947\u0902" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "them",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0909\u0928\u0915\u0947" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Their",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u092c\u0924\u093e\u090f" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Tell",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0916\u0947\u0932" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "sport",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0938\u0947" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "From",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0926\u0947\u0924\u093e" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Gives",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u091d\u0942\u0920\u092e\u0942\u0920" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Alie",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0930\u094b\u0928\u0947" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Tocry",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u090f\u0915\u094d\u091f\u093f\u0902\u0917" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Acting",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0915\u0930\u0924\u0947" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "do",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0939\u0941\u090f" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Happened",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0905\u0930\u0947" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Hey",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0932\u095c\u0915\u093e" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Theboy",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u092c\u0939\u0941\u0924" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "very",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0924\u0947\u091c" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "fast",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0939\u094b" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Ho",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0917\u092f\u093e" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Gone",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0939\u0948" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "is",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u092c\u094b\u0932\u0947" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Speak",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u092e\u0941\u091d\u0947" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "me",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0932\u0917\u0924\u093e" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Seems",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0938\u094d\u092a\u0947\u0938\u0936\u093f\u092a" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Spaceship",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u092c\u0928\u0915\u0930" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "bemade",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u091a\u093e\u0902\u0926" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Themoon",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u091a\u0932\u0940" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Lasted",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0917\u0908" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Hasgone",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0939\u093e\u0902" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Yes",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0928\u0902\u092c\u0930" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Number",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0926\u094b" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "two",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0909\u0938\u0915\u093e" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "His",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u092a\u0942\u091b\u0942\u0902\u0917\u093e" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Willask",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0920\u0940\u0915" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Fine",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u092c\u0917\u0940\u091a\u0947" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Thegarden",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0924" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "T",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u092e\u0939\u093e\u0924\u094d\u092e\u093e" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Mahatma",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0917\u093e\u0902\u0927\u0940" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Gandhi",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0936\u093e\u0938\u0928" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Governance",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u092c\u094d\u0930\u093f\u091f\u093f\u0936" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Thebritish",
#      "weight" : 1.0
#  }]

# %% [markdown]
# Let's add states to our model:

# %%
hmm_model.add_states()

# %% [markdown]
# The start probability for each tag is how many times it is a sentence-starting POS tag divided by its total count. We build the starting transitions for our HMM model:

# %%
start_prob={}

for tag in tags:
    start_prob[tag] = starting_tag_count[tag] / tags_count[tag]

for tag_state in to_pass_states :
    hmm_model.add_transition(hmm_model.start, tag_state, start_prob[tag_state.name])

# %% [markdown]
# The end probability for each tag is how many times it is a sentence-ending POS tag divided by its total count. We build the ending transitions for our HMM model:

# %%
end_prob={}

for tag in tags:
    end_prob[tag] = ending_tag_count[tag]/tags_count[tag]
    
for tag_state in to_pass_states :
    hmm_model.add_transition(tag_state, hmm_model.end, end_prob[tag_state.name])

# %%
tags
# Out:
# ['One',
#  'flowerpot',
#  'In',
#  'Small',
#  'Yellow',
#  'Oranges',
#  'so',
#  'Others',
#  'In',
#  'One',
#  'Apple',
#  'And',
#  'Third',
#  'In',
#  'One',
#  'lemon',
#  'Hang',
#  'Was',
#  'between',
#  'In',
#  'Green',
#  'Grass',
#  'Only',
#  'Grass',
#  'was',
#  'evening',
#  'Of',
#  'Time',
#  'sometimes',
#  'dad',
#  'sometimes',
#  "father'ssister",
#  'sometimes',
#  'Mummy',
#  'Of',
#  'with',
#  'that',
#  'Tennis',
#  'Badminton',
#  'or',
#  'Football',
#  'Plays',
#  'Was',
#  'Toeveryone',
#  'with',
#  'that',
#  'Plenty',
#  'fun',
#  'Does',
#  'TV',
#  'On',
#  'Football',
#  'Theplayers',
#  'To',
#  'See',
#  'something',
#  'bytheway',
#  'Only',
#  'Feat',
#  'Todo',
#  'Of',
#  'try',
#  'Does',
#  'his',
#  'after',
#  'day',
#  'Of',
#  'time',
#  'grandfatherSir',
#  'Of',
#  'with',
#  'Chess',
#  'Plays',
#  'Play',
#  'time',
#  'grandfatherSir',
#  'Fromhim',
#  'Say',
#  'Look',
#  'if',
#  'you',
#  'this',
#  'Trick',
#  'Willyougo',
#  'so',
#  'Iam',
#  'Your',
#  'Thehorses',
#  'To',
#  'Kill',
#  'Give',
#  'grandfatherSir',
#  'Him',
#  'every',
#  'condition',
#  'In',
#  'Jita',
#  'give',
#  'Want',
#  'Were',
#  'All',
#  'Laughs',
#  'when',
#  'Space',
#  'them',
#  'Their',
#  'Only',
#  'Tell',
#  'sport',
#  'From',
#  'Green',
#  'Gives',
#  'so',
#  'that',
#  'Alie',
#  'Tocry',
#  'Of',
#  'Acting',
#  'do',
#  'Happened',
#  'Say',
#  'Hey',
#  'this',
#  'Theboy',
#  'so',
#  'very',
#  'fast',
#  'Ho',
#  'Gone',
#  'is',
#  'dad',
#  'Speak',
#  'me',
#  'so',
#  'Seems',
#  'is',
#  'his',
#  'Football',
#  'Spaceship',
#  'bemade',
#  'Themoon',
#  'On',
#  'Lasted',
#  'Hasgone',
#  'is',
#  'Yes',
#  'dad',
#  'Number',
#  'two',
#  'His',
#  'Iam',
#  'Willask',
#  'Fine',
#  'is',
#  'Fine',
#  'is',
#  'Space',
#  'Of',
#  'Thegarden',
#  'In',
#  'T',
#  'Space',
#  'Of',
#  'Thegarden',
#  'T',
#  'In',
#  'Space',
#  'Of',
#  'In',
#  'Thegarden',
#  'T',
#  'Space',
#  'Of',
#  'In',
#  'T',
#  'Thegarden',
#  'Space',
#  'Of',
#  'T',
#  'Thegarden',
#  'In',
#  'Space',
#  'Of',
#  'T',
#  'In',
#  'Thegarden',
#  'Space',
#  'Thegarden',
#  'Of',
#  'In',
#  'T',
#  'Space',
#  'Thegarden',
#  'Of',
#  'T',
#  'In',
#  'Space',
#  'Thegarden',
#  'In',
#  'Of',
#  'T',
#  'Space',
#  'Thegarden',
#  'In',
#  'T',
#  'Of',
#  'Space',
#  'Thegarden',
#  'T',
#  'Of',
#  'In',
#  'Space',
#  'Thegarden',
#  'T',
#  'In',
#  'Of',
#  'Space',
#  'In',
#  'Of',
#  'Thegarden',
#  'T',
#  'Space',
#  'In',
#  'Of',
#  'T',
#  'Thegarden',
#  'Space',
#  'In',
#  'Thegarden',
#  'Of',
#  'T',
#  'Space',
#  'In',
#  'Thegarden',
#  'T',
#  'Of',
#  'Space',
#  'In',
#  'T',
#  'Of',
#  'Thegarden',
#  'Space',
#  'In',
#  'T',
#  'Thegarden',
#  'Of',
#  'Space',
#  'T',
#  'Of',
#  'Thegarden',
#  'In',
#  'Space',
#  'T',
#  'Of',
#  'In',
#  'Thegarden',
#  'Space',
#  'T',
#  'Thegarden',
#  'Of',
#  'In',
#  'Space',
#  'T',
#  'Thegarden',
#  'In',
#  'Of',
#  'Space',
#  'T',
#  'In',
#  'Of',
#  'Thegarden',
#  'Space',
#  'T',
#  'In',
#  'Thegarden',
#  'Of',
#  'Of',
#  'Space',
#  'Thegarden',
#  'In',
#  'T',
#  'Of',
#  'Space',
#  'Thegarden',
#  'T',
#  'In',
#  'Of',
#  'Space',
#  'In',
#  'Thegarden',
#  'T',
#  'Of',
#  'Space',
#  'In',
#  'T',
#  'Thegarden',
#  'Of',
#  'Space',
#  'T',
#  'Thegarden',
#  'In',
#  'Of',
#  'Space',
#  'T',
#  'In',
#  'Thegarden',
#  'Of',
#  'Thegarden',
#  'Space',
#  'In',
#  'T',
#  'Of',
#  'Thegarden',
#  'Space',
#  'T',
#  'In',
#  'Of',
#  'Thegarden',
#  'In',
#  'Space',
#  'T',
#  'Of',
#  'Thegarden',
#  'In',
#  'T',
#  'Space',
#  'Of',
#  'Thegarden',
#  'T',
#  'Space',
#  'In',
#  'Of',
#  'Thegarden',
#  'T',
#  'In',
#  'Space',
#  'Of',
#  'In',
#  'Space',
#  'Thegarden',
#  'T',
#  'Of',
#  'In',
#  'Space',
#  'T',
#  'Thegarden',
#  'Of',
#  'In',
#  'Thegarden',
#  'Space',
#  'T',
#  'Of',
#  'In',
#  'Thegarden',
#  'T',
#  'Space',
#  'Of',
#  'In',
#  'T',
#  'Space',
#  'Thegarden',
#  'Of',
#  'In',
#  'T',
#  'Thegarden',
#  'Space',
#  'Of',
#  'T',
#  'Space',
#  'Thegarden',
#  'In',
#  'Of',
#  'T',
#  'Space',
#  'In',
#  'Thegarden',
#  'Of',
#  'T',
#  'Thegarden',
#  'Space',
#  'In',
#  'Of',
#  'T',
#  'Thegarden',
#  'In',
#  'Space',
#  'Of',
#  'T',
#  'In',
#  'Space',
#  'Thegarden',
#  'Of',
#  'T',
#  'In',
#  'Thegarden',
#  'Space',
#  'Thegarden',
#  'Space',
#  'Of',
#  'In',
#  'T',
#  'Thegarden',
#  'Space',
#  'Of',
#  'T',
#  'In',
#  'Thegarden',
#  'Space',
#  'In',
#  'Of',
#  'T',
#  'Thegarden',
#  'Space',
#  'In',
#  'T',
#  'Of',
#  'Thegarden',
#  'Space',
#  'T',
#  'Of',
#  'In',
#  'Thegarden',
#  'Space',
#  'T',
#  'In',
#  'Of',
#  'Thegarden',
#  'Of',
#  'Space',
#  'In',
#  'T',
#  'Thegarden',
#  'Of',
#  'Space',
#  'T',
#  'In',
#  'Thegarden',
#  'Of',
#  'In',
#  'Space',
#  'T',
#  'Thegarden',
#  'Of',
#  'In',
#  'T',
#  'Space',
#  'Thegarden',
#  'Of',
#  'T',
#  'Space',
#  'In',
#  'Thegarden',
#  'Of',
#  'T',
#  'In',
#  'Space',
#  'Thegarden',
#  'In',
#  'Space',
#  'Of',
#  'T',
#  'Thegarden',
#  'In',
#  'Space',
#  'T',
#  'Of',
#  'Thegarden',
#  'In',
#  'Of',
#  'Space',
#  'T',
#  'Thegarden',
#  'In',
#  'Of',
#  'T',
#  'Space',
#  'Thegarden',
#  'In',
#  'T',
#  'Space',
#  'Of',
#  'Thegarden',
#  'In',
#  'T',
#  'Of',
#  'Space',
#  'Thegarden',
#  'T',
#  'Space',
#  'Of',
#  'In',
#  'Thegarden',
#  'T',
#  'Space',
#  'In',
#  'Of',
#  'Thegarden',
#  'T',
#  'Of',
#  'Space',
#  'In',
#  'Thegarden',
#  'T',
#  'Of',
#  'In',
#  'Space',
#  'Thegarden',
#  'T',
#  'In',
#  'Space',
#  'Of',
#  'Thegarden',
#  'T',
#  'In',
#  'Of',
#  'Space',
#  'In',
#  'Space',
#  'Of',
#  'Thegarden',
#  'T',
#  'In',
#  'Space',
#  'Of',
#  'T',
#  'Thegarden',
#  'In',
#  'Space',
#  'Thegarden',
#  'Of',
#  'T',
#  'In',
#  'Space',
#  'Thegarden',
#  'T',
#  'Of',
#  'In',
#  'Space',
#  'T',
#  'Of',
#  'Thegarden',
#  'In',
#  'Space',
#  'T',
#  'Thegarden',
#  'Of',
#  'In',
#  'Of',
#  'Space',
#  'Thegarden',
#  'T',
#  'In',
#  'Of',
#  'Space',
#  'T',
#  'Thegarden',
#  'In',
#  'Of',
#  'Thegarden',
#  'Space',
#  'T',
#  'In',
#  'Of',
#  'Thegarden',
#  'T',
#  'Space',
#  'In',
#  'Of',
#  'T',
#  'Space',
#  'Thegarden',
#  'In',
#  'Of',
#  'T',
#  'Thegarden',
#  'Space',
#  'In',
#  'Thegarden',
#  'Space',
#  'Of',
#  'T',
#  'In',
#  'Thegarden',
#  'Space',
#  'T',
#  'Of',
#  'In',
#  'Thegarden',
#  'Of',
#  'Space',
#  'T',
#  'In',
#  'Thegarden',
#  'Of',
#  'T',
#  'Space',
#  'In',
#  'Thegarden',
#  'T',
#  'Space',
#  'Of',
#  'In',
#  'Thegarden',
#  'T',
#  'Of',
#  'Space',
#  'In',
#  'T',
#  'Space',
#  'Of',
#  'Thegarden',
#  'In',
#  'T',
#  'Space',
#  'Thegarden',
#  'Of',
#  'In',
#  'T',
#  'Of',
#  'Space',
#  'Thegarden',
#  'In',
#  'T',
#  'Of',
#  'Thegarden',
#  'Space',
#  'In',
#  'T',
#  'Thegarden',
#  'Space',
#  'Of',
#  'In',
#  'T',
#  'Thegarden',
#  'Of',
#  'Space',
#  'T',
#  'Space',
#  'Of',
#  'Thegarden',
#  'In',
#  'T',
#  'Space',
#  'Of',
#  'In',
#  'Thegarden',
#  'T',
#  'Space',
#  'Thegarden',
#  'Of',
#  'In',
#  'T',
#  'Space',
#  'Thegarden',
#  'In',
#  'Of',
#  'T',
#  'Space',
#  'In',
#  'Of',
#  'Thegarden',
#  'T',
#  'Space',
#  'In',
#  'Thegarden',
#  'Of',
#  'T',
#  'Of',
#  'Space',
#  'Thegarden',
#  'In',
#  'T',
#  'Of',
#  'Space',
#  'In',
#  'Thegarden',
#  'T',
#  'Of',
#  'Thegarden',
#  'Space',
#  'In',
#  'T',
#  'Of',
#  'Thegarden',
#  'In',
#  'Space',
#  'T',
#  'Of',
#  'In',
#  'Space',
#  'Thegarden',
#  'T',
#  'Of',
#  'In',
#  'Thegarden',
#  'Space',
#  'T',
#  'Thegarden',
#  'Space',
#  'Of',
#  'In',
#  'T',
#  'Thegarden',
#  'Space',
#  'In',
#  'Of',
#  'T',
#  'Thegarden',
#  'Of',
#  'Space',
#  'In',
#  'T',
#  'Thegarden',
#  'Of',
#  'In',
#  'Space',
#  'T',
#  'Thegarden',
#  'In',
#  'Space',
#  'Of',
#  'T',
#  'Thegarden',
#  'In',
#  'Of',
#  'Space',
#  'T',
#  'In',
#  'Space',
#  'Of',
#  'Thegarden',
#  'T',
#  'In',
#  'Space',
#  'Thegarden',
#  'Of',
#  'T',
#  'In',
#  'Of',
#  'Space',
#  'Thegarden',
#  'T',
#  'In',
#  'Of',
#  'Thegarden',
#  'Space',
#  'T',
#  'In',
#  'Thegarden',
#  'Space',
#  'Of',
#  'T',
#  'In',
#  'Thegarden',
#  'Of',
#  'Space',
#  'Mahatma',
#  'Gandhi',
#  'To',
#  'Governance',
#  'Thebritish',
#  'Mahatma',
#  'Gandhi',
#  'Thebritish',
#  'To',
#  'Governance',
#  'Mahatma',
#  'Gandhi',
#  'Thebritish',
#  'Governance',
#  'To',
#  'Mahatma',
#  'Gandhi',
#  'Governance',
#  'To',
#  'Thebritish',
#  'Mahatma',
#  'Gandhi',
#  'Governance',
#  'Thebritish',
#  'To',
#  'Mahatma',
#  'To',
#  'Gandhi',
#  'Thebritish',
#  'Governance',
#  'Mahatma',
#  'To',
#  'Gandhi',
#  'Governance',
#  'Thebritish',
#  'Mahatma',
#  'To',
#  'Thebritish',
#  'Gandhi',
#  'Governance',
#  'Mahatma',
#  'To',
#  'Thebritish',
#  'Governance',
#  'Gandhi',
#  'Mahatma',
#  'To',
#  'Governance',
#  'Gandhi',
#  'Thebritish',
#  'Mahatma',
#  'To',
#  'Governance',
#  'Thebritish',
#  'Gandhi',
#  'Mahatma',
#  'Thebritish',
#  'Gandhi',
#  'To',
#  'Governance',
#  'Mahatma',
#  'Thebritish',
#  'Gandhi',
#  'Governance',
#  'To',
#  'Mahatma',
#  'Thebritish',
#  'To',
#  'Gandhi',
#  'Governance',
#  'Mahatma',
#  'Thebritish',
#  'To',
#  'Governance',
#  'Gandhi',
#  'Mahatma',
#  'Thebritish',
#  'Governance',
#  'Gandhi',
#  'To',
#  'Mahatma',
#  'Thebritish',
#  'Governance',
#  'To',
#  'Gandhi',
#  'Mahatma',
#  'Governance',
#  'Gandhi',
#  'To',
#  'Thebritish',
#  'Mahatma',
#  'Governance',
#  'Gandhi',
#  'Thebritish',
#  'To',
#  'Mahatma',
#  'Governance',
#  'To',
#  'Gandhi',
#  'Thebritish',
#  'Mahatma',
#  'Governance',
#  'To',
#  'Thebritish',
#  'Gandhi',
#  'Mahatma',
#  'Governance',
#  'Thebritish',
#  'Gandhi',
#  'To',
#  'Mahatma',
#  'Governance',
#  'Thebritish',
#  'To',
#  'Gandhi',
#  'Gandhi',
#  'Mahatma',
#  'To',
#  'Thebritish',
#  'Governance',
#  'Gandhi',
#  'Mahatma',
#  'To',
#  'Governance',
#  'Thebritish',
#  'Gandhi',
#  'Mahatma',
#  'Thebritish',
#  'To',
#  'Governance',
#  'Gandhi',
#  'Mahatma',
#  'Thebritish',
#  'Governance',
#  'To',
#  'Gandhi',
#  'Mahatma',
#  'Governance',
#  'To',
#  'Thebritish',
#  'Gandhi',
#  'Mahatma',
#  'Governance',
#  'Thebritish',
#  'To',
#  'Gandhi',
#  'To',
#  'Mahatma',
#  'Thebritish',
#  'Governance',
#  'Gandhi',
#  'To',
#  'Mahatma',
#  'Governance',
#  'Thebritish',
#  'Gandhi',
#  'To',
#  'Thebritish',
#  'Mahatma',
#  'Governance',
#  'Gandhi',
#  'To',
#  'Thebritish',
#  'Governance',
#  'Mahatma',
#  'Gandhi',
#  'To',
#  'Governance',
#  'Mahatma',
#  'Thebritish',
#  'Gandhi',
#  'To',
#  'Governance',
#  'Thebritish',
#  'Mahatma',
#  'Gandhi',
#  'Thebritish',
#  'Mahatma',
#  'To',
#  'Governance',
#  'Gandhi',
#  'Thebritish',
#  'Mahatma',
#  'Governance',
#  'To',
#  'Gandhi',
#  'Thebritish',
#  'To',
#  'Mahatma',
#  'Governance',
#  'Gandhi',
#  'Thebritish',
#  'To',
#  'Governance',
#  'Mahatma',
#  'Gandhi',
#  'Thebritish',
#  'Governance',
#  'Mahatma',
#  'To',
#  'Gandhi',
#  'Thebritish',
#  'Governance',
#  'To',
#  'Mahatma',
#  'Gandhi',
#  'Governance',
#  'Mahatma',
#  'To',
#  'Thebritish',
#  'Gandhi',
#  'Governance',
#  'Mahatma',
#  'Thebritish',
#  'To',
#  'Gandhi',
#  'Governance',
#  'To',
#  'Mahatma',
#  'Thebritish',
#  'Gandhi',
#  'Governance',
#  'To',
#  'Thebritish',
#  'Mahatma',
#  'Gandhi',
#  'Governance',
#  'Thebritish',
#  'Mahatma',
#  'To',
#  'Gandhi',
#  'Governance',
#  'Thebritish',
#  'To',
#  'Mahatma',
#  'To',
#  'Mahatma',
#  'Gandhi',
#  'Thebritish',
#  'Governance',
#  'To',
#  'Mahatma',
#  'Gandhi',
#  'Governance',
#  ...]

# %%
to_pass_states
# Out:
# [{
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u090f\u0915" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "One",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0917\u092e\u0932\u0947" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "flowerpot",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u092e\u0947\u0902" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "In",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u091b\u094b\u091f\u0947" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Small",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u092a\u0940\u0932\u0947" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Yellow",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0938\u0902\u0924\u0930\u0947" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Oranges",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0924\u094b" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "so",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0926\u0942\u0938\u0930\u0947" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Others",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0938\u0947\u092c" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Apple",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0914\u0930" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "And",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0924\u0940\u0938\u0930\u0947" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Third",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0928\u0940\u092c\u0942" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "lemon",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0932\u091f\u0915\u093e" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Hang",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0925\u093e" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Was",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u092c\u0940\u091a" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "between",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0939\u0930\u0940\u0939\u0930\u0940" : 0.5,
#                  "\u0939\u0930\u093e" : 0.5
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Green",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0918\u093e\u0938" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Grass",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0939\u0940" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Only",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0925\u0940" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "was",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0936\u093e\u092e" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "evening",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0915\u0947" : 0.9841269841269841,
#                  "\u0915\u0940" : 0.015873015873015872
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Of",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0938\u092e\u092f" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Time",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0915\u092d\u0940" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "sometimes",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u092a\u093e\u092a\u093e" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "dad",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u092c\u0941\u0906" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "father'ssister",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u092e\u092e\u094d\u092e\u0940" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Mummy",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0938\u093e\u0925" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "with",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0935\u0939" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "that",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u091f\u0947\u0928\u093f\u0938" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Tennis",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u092c\u0948\u0921\u092e\u093f\u0902\u091f\u0928" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Badminton",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u092f\u093e" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "or",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u092b\u0941\u091f\u092c\u0949\u0932" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Football",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0916\u0947\u0932\u0924\u093e" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Plays",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0938\u092c\u0915\u0947" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Toeveryone",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0916\u0942\u092c" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Plenty",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u092e\u0938\u094d\u0924\u0940" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "fun",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0915\u0930\u0924\u093e" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Does",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u091f\u0940\u0935\u0940" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "TV",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u092a\u0930" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "On",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0916\u093f\u0932\u093e\u095c\u093f\u092f\u094b\u0902" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Theplayers",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0915\u094b" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "To",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0926\u0947\u0916" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "See",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0915\u0941\u091b\u0915\u0941\u091b" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "something",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0935\u0948\u0938\u0947" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "bytheway",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0915\u0930\u0924\u092c" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Feat",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0915\u0930\u0928\u0947" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Todo",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0915\u094b\u0936\u093f\u0936" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "try",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0909\u0938\u0915\u0947" : 0.5,
#                  "\u0907\u0938\u0915\u0940" : 0.5
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "his",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u092c\u093e\u0926" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "after",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0926\u093f\u0928" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "day",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0935\u0915\u094d\u0924" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "time",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0926\u093e\u0926\u093e\u091c\u0940" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "grandfatherSir",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0936\u0924\u0930\u0902\u091c" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Chess",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0916\u0947\u0932\u0924\u0947" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Play",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0909\u0938\u0938\u0947" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Fromhim",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0915\u0939\u0924\u0947" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Say",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0926\u0947\u0916\u094b" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Look",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0905\u0917\u0930" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "if",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0924\u0941\u092e" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "you",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u092f\u0939" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "this",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u091a\u093e\u0932" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Trick",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u091a\u0932\u094b\u0917\u0947" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Willyougo",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u092e\u0948\u0902" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Iam",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0924\u0941\u092e\u094d\u0939\u093e\u0930\u0947" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Your",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0918\u094b\u095c\u0947" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Thehorses",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u092e\u093e\u0930" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Kill",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0926\u0942\u0902\u0917\u093e" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Give",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0909\u0938\u0947" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Him",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0939\u0930" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "every",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0939\u093e\u0932" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "condition",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u091c\u093f\u0924\u093e" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Jita",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0926\u0947\u0928\u093e" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "give",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u091a\u093e\u0939\u0924\u0947" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Want",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0925\u0947" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Were",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0938\u092c" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "All",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0939\u0902\u0938\u0924\u0947" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Laughs",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u091c\u092c" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "when",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0905\u0902\u0924\u0930\u093f\u0915\u094d\u0937" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Space",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0909\u0928\u094d\u0939\u0947\u0902" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "them",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0909\u0928\u0915\u0947" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Their",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u092c\u0924\u093e\u090f" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Tell",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0916\u0947\u0932" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "sport",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0938\u0947" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "From",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0926\u0947\u0924\u093e" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Gives",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u091d\u0942\u0920\u092e\u0942\u0920" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Alie",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0930\u094b\u0928\u0947" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Tocry",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u090f\u0915\u094d\u091f\u093f\u0902\u0917" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Acting",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0915\u0930\u0924\u0947" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "do",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0939\u0941\u090f" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Happened",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0905\u0930\u0947" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Hey",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0932\u095c\u0915\u093e" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Theboy",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u092c\u0939\u0941\u0924" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "very",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0924\u0947\u091c" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "fast",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0939\u094b" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Ho",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0917\u092f\u093e" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Gone",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0939\u0948" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "is",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u092c\u094b\u0932\u0947" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Speak",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u092e\u0941\u091d\u0947" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "me",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0932\u0917\u0924\u093e" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Seems",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0938\u094d\u092a\u0947\u0938\u0936\u093f\u092a" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Spaceship",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u092c\u0928\u0915\u0930" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "bemade",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u091a\u093e\u0902\u0926" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Themoon",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u091a\u0932\u0940" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Lasted",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0917\u0908" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Hasgone",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0939\u093e\u0902" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Yes",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0928\u0902\u092c\u0930" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Number",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0926\u094b" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "two",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0909\u0938\u0915\u093e" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "His",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u092a\u0942\u091b\u0942\u0902\u0917\u093e" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Willask",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0920\u0940\u0915" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Fine",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u092c\u0917\u0940\u091a\u0947" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Thegarden",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0924" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "T",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u092e\u0939\u093e\u0924\u094d\u092e\u093e" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Mahatma",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0917\u093e\u0902\u0927\u0940" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Gandhi",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0936\u093e\u0938\u0928" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Governance",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u092c\u094d\u0930\u093f\u091f\u093f\u0936" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Thebritish",
#      "weight" : 1.0
#  }]

# %% [markdown]
# We now add the transition probabilities for our model, which uses our POS bigrams to enumerate what the probabilities are for transiting from one POS tag to another.

# %%
transition_prob_pair={}

for key in tag_bigrams.keys():
    transition_prob_pair[key] = tag_bigrams.get(key)/tags_count[key[0]]
    
for tag_state in to_pass_states:
    for next_tag_state in to_pass_states:
        if ((tag_state.name, next_tag_state.name) in transition_prob_pair):
            hmm_model.add_transition(tag_state, next_tag_state, transition_prob_pair[(tag_state.name, next_tag_state.name)])

# %%
transition_prob_pair
# Out:
# {('One', 'flowerpot'): 0.3333333333333333,
#  ('In', 'Small'): 0.008,
#  ('Yellow', 'Oranges'): 1.0,
#  ('so', 'Others'): 0.2,
#  ('In', 'One'): 0.008,
#  ('Apple', 'And'): 1.0,
#  ('Third', 'In'): 1.0,
#  ('One', 'lemon'): 0.3333333333333333,
#  ('Hang', 'Was'): 1.0,
#  ('between', 'In'): 1.0,
#  ('Green', 'Grass'): 0.5,
#  ('Only', 'Grass'): 0.3333333333333333,
#  ('was', 'evening'): 1.0,
#  ('Of', 'Time'): 0.007936507936507936,
#  ('sometimes', 'dad'): 0.3333333333333333,
#  ('sometimes', "father'ssister"): 0.3333333333333333,
#  ('sometimes', 'Mummy'): 0.3333333333333333,
#  ('Of', 'with'): 0.007936507936507936,
#  ('that', 'Tennis'): 0.3333333333333333,
#  ('Badminton', 'or'): 1.0,
#  ('Football', 'Plays'): 0.3333333333333333,
#  ('Was', 'Toeveryone'): 0.5,
#  ('with', 'that'): 0.3333333333333333,
#  ('Plenty', 'fun'): 1.0,
#  ('Does', 'TV'): 0.5,
#  ('On', 'Football'): 0.5,
#  ('Theplayers', 'To'): 1.0,
#  ('See', 'something'): 1.0,
#  ('bytheway', 'Only'): 1.0,
#  ('Feat', 'Todo'): 1.0,
#  ('Of', 'try'): 0.007936507936507936,
#  ('Does', 'his'): 0.5,
#  ('after', 'day'): 1.0,
#  ('Of', 'time'): 0.007936507936507936,
#  ('grandfatherSir', 'Of'): 0.3333333333333333,
#  ('with', 'Chess'): 0.3333333333333333,
#  ('Plays', 'Play'): 0.5,
#  ('time', 'grandfatherSir'): 0.5,
#  ('Fromhim', 'Say'): 1.0,
#  ('Look', 'if'): 1.0,
#  ('you', 'this'): 1.0,
#  ('Trick', 'Willyougo'): 1.0,
#  ('so', 'Iam'): 0.2,
#  ('Your', 'Thehorses'): 1.0,
#  ('To', 'Kill'): 0.008333333333333333,
#  ('Give', 'grandfatherSir'): 1.0,
#  ('Him', 'every'): 1.0,
#  ('condition', 'In'): 1.0,
#  ('Jita', 'give'): 1.0,
#  ('Want', 'Were'): 1.0,
#  ('All', 'Laughs'): 1.0,
#  ('when', 'Space'): 1.0,
#  ('them', 'Their'): 1.0,
#  ('Only', 'Tell'): 0.3333333333333333,
#  ('sport', 'From'): 1.0,
#  ('Green', 'Gives'): 0.5,
#  ('so', 'that'): 0.2,
#  ('Alie', 'Tocry'): 1.0,
#  ('Of', 'Acting'): 0.007936507936507936,
#  ('do', 'Happened'): 1.0,
#  ('Say', 'Hey'): 0.5,
#  ('this', 'Theboy'): 0.5,
#  ('so', 'very'): 0.2,
#  ('fast', 'Ho'): 1.0,
#  ('Gone', 'is'): 1.0,
#  ('dad', 'Speak'): 0.3333333333333333,
#  ('me', 'so'): 1.0,
#  ('Seems', 'is'): 1.0,
#  ('his', 'Football'): 0.5,
#  ('Spaceship', 'bemade'): 1.0,
#  ('Themoon', 'On'): 1.0,
#  ('Lasted', 'Hasgone'): 1.0,
#  ('is', 'Yes'): 0.2,
#  ('dad', 'Number'): 0.3333333333333333,
#  ('two', 'His'): 1.0,
#  ('Iam', 'Willask'): 0.5,
#  ('Fine', 'is'): 1.0,
#  ('Space', 'Of'): 0.09917355371900827,
#  ('Thegarden', 'In'): 0.1,
#  ('T', 'Space'): 0.2,
#  ('Of', 'Thegarden'): 0.09523809523809523,
#  ('T', 'In'): 0.15,
#  ('In', 'Thegarden'): 0.144,
#  ('Of', 'In'): 0.07936507936507936,
#  ('T', 'Thegarden'): 0.16666666666666666,
#  ('In', 'Space'): 0.176,
#  ('Of', 'T'): 0.06349206349206349,
#  ('Space', 'Thegarden'): 0.08264462809917356,
#  ('Thegarden', 'Of'): 0.15,
#  ('In', 'Of'): 0.16,
#  ('T', 'Of'): 0.18333333333333332,
#  ('Thegarden', 'T'): 0.08333333333333333,
#  ('Space', 'In'): 0.06611570247933884,
#  ('Thegarden', 'Space'): 0.16666666666666666,
#  ('In', 'T'): 0.096,
#  ('Space', 'T'): 0.049586776859504134,
#  ('Of', 'Space'): 0.14285714285714285,
#  ('Mahatma', 'Gandhi'): 0.13559322033898305,
#  ('To', 'Governance'): 0.16666666666666666,
#  ('Thebritish', 'Mahatma'): 0.06779661016949153,
#  ('Gandhi', 'Thebritish'): 0.1694915254237288,
#  ('Thebritish', 'Governance'): 0.1440677966101695,
#  ('To', 'Mahatma'): 0.08333333333333333,
#  ('Gandhi', 'Governance'): 0.1864406779661017,
#  ('To', 'Thebritish'): 0.15,
#  ('Governance', 'Thebritish'): 0.09322033898305085,
#  ('To', 'Gandhi'): 0.09166666666666666,
#  ('Mahatma', 'To'): 0.1694915254237288,
#  ('Gandhi', 'Mahatma'): 0.09322033898305085,
#  ('Thebritish', 'Gandhi'): 0.0847457627118644,
#  ('Mahatma', 'Thebritish'): 0.1864406779661017,
#  ('Thebritish', 'To'): 0.1016949152542373,
#  ('Gandhi', 'To'): 0.1440677966101695,
#  ('Governance', 'To'): 0.0847457627118644,
#  ('Governance', 'Gandhi'): 0.06779661016949153,
#  ('Mahatma', 'Governance'): 0.2033898305084746,
#  ('Gandhi', 'Gandhi'): 0.00847457627118644,
#  ('Governance', 'Mahatma'): 0.05084745762711865}

# %% [markdown]
# We *bake* our model:

# %%
hmm_model.bake()

# %% [markdown]
# We can now evaluate the accuracy of our HMM model and compare it to our BOW model:

# %%
hmm_training_acc = accuracy(data.training_set.X, data.training_set.Y, hmm_model)
print("training accuracy basic hmm model: {:.2f}%".format(100 * hmm_training_acc))

hmm_testing_acc = accuracy(data.testing_set.X, data.testing_set.Y, hmm_model)
print("testing accuracy basic hmm model: {:.2f}%".format(100 * hmm_testing_acc))
# Out:
# training accuracy basic hmm model: 88.77%
# testing accuracy basic hmm model: 88.45%
