# %%
import pandas as pd
import pycountry
import wbdata
import datetime
import statsmodels.formula.api as smf
import numpy as np
import pylab
import matplotlib
import matplotlib.pyplot as plt

# %%
ODA_Production = pd.read_csv('Production.csv')

# %%
ODA_Production = ODA_Production.drop(['INDICATOR', 'SUBJECT', 'MEASURE', 'FREQUENCY', 'Flag Codes'], axis=1)

# %%
ODA_Production
# Out:
#     LOCATION  TIME   Value
# 0        AUS  2000  118.41
# 1        AUS  2001  138.29
# 2        AUS  2002  119.38
# 3        AUS  2003  124.27
# 4        AUS  2004  120.55
# ..       ...   ...     ...
# 545      LVA  2018    0.06
# 546      SAU  2016  154.76
# 547      SAU  2017   90.00
# 548      SAU  2018   95.05
# 549      CYP  2018    0.10
#
# [550 rows x 3 columns]

# %%
ODA_Production.rename(columns ={'LOCATION': 'Code', 'Value': 'Millions($)', 'TIME': 'Time'}, inplace = True)

# %%
ODA_Production
# Out:
#     Code  Time  Millions($)
# 0    AUS  2000       118.41
# 1    AUS  2001       138.29
# 2    AUS  2002       119.38
# 3    AUS  2003       124.27
# 4    AUS  2004       120.55
# ..   ...   ...          ...
# 545  LVA  2018         0.06
# 546  SAU  2016       154.76
# 547  SAU  2017        90.00
# 548  SAU  2018        95.05
# 549  CYP  2018         0.10
#
# [550 rows x 3 columns]

# %%
# We need country codes for this. We need unique countries code.. 
ODA_Production_2018 = ODA_Production[ODA_Production['Time']==2018]

len(ODA_Production_2018)
# Out:
# 39

# %%
ODA_Production_2018
# Out:
#     Code  Time  Millions($)
# 18   AUS  2018       222.30
# 37   AUT  2018        34.67
# 56   BEL  2018        74.27
# 75   CAN  2018       247.69
# 92   CZE  2018         5.09
# 111  DNK  2018        81.19
# 130  FIN  2018        47.74
# 149  FRA  2018       856.46
# 168  DEU  2018      1103.60
# 188  ISL  2018         3.80
# 207  IRL  2018        31.56
# 226  ITA  2018       132.76
# 245  JPN  2018      1431.61
# 264  KOR  2018       394.53
# 280  LUX  2018        27.17
# 299  NLD  2018       437.03
# 318  NZL  2018        37.68
# 337  NOR  2018       196.59
# 356  PRT  2018         4.10
# 375  ESP  2018        70.47
# 394  SWE  2018       292.16
# 413  CHE  2018       230.48
# 431  TUR  2018        10.98
# 450  GBR  2018      1046.29
# 469  USA  2018      1390.66
# 479  ARE  2018         9.59
# 498  DAC  2018      8445.70
# 504  POL  2018        34.56
# 510  SVK  2018         0.33
# 516  EST  2018         0.37
# 523  SVN  2018         0.30
# 528  HUN  2018        10.58
# 533  LTU  2018         0.13
# 537  ROU  2018         0.04
# 540  RUS  2018        11.83
# 542  BGR  2018         0.08
# 545  LVA  2018         0.06
# 548  SAU  2018        95.05
# 549  CYP  2018         0.10

# %%
ODA_Production_2018 = ODA_Production_2018[ODA_Production_2018.Code != 'DAC']

# %%
def get_codes_list(df_data):
    """Create a list of countries codes from column Code in df_data
    change code for OECD members from OAVG to OED
    :param df_data: data frame
    :returns codes_list: list"""
    codes_list = df_data['Code'].tolist()

    #    codes_list.remove('OAVG')
  #  codes_list.append('OED')
    return codes_list

#get list of countries, who took PISA test
countries_codes = get_codes_list(ODA_Production_2018)

# %%
countries_codes = countries_codes.remove('DAC')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-38-8a91d3cea0a1> in <module>
# ----> 1 countries_codes = countries_codes.remove('DAC')
#
# ValueError: list.remove(x): x not in list

# %%
def create_name_code_dict():
    """Use pycountry library to create a map for converting from country name to country code
    :returns name_code_dict: dictionary"""
    name_code_dict = {country.name: country.alpha_3 for country in pycountry.countries}
    dict_adjust = {'Czech Republic': 'CZE', 'Hong Kong SAR, China': 'HKG', 'Korea, Rep.': 'KOR',
                      'Macao SAR, China': 'MAC', 'OECD members': 'OED', 'Slovak Republic': 'SVK',
                  'China, Hong Kong Special Administrative Region': 'HKG', 'China, Macao Special Administrative Region': 'MAC',
                  'Republic of Korea': 'KOR', 'United Kingdom of Great Britain and Northern Ireland': 'GBR',
                  'United States of America': 'USA', 'OECD members': 'OAVG'}
    name_code_dict.update(dict_adjust)
    return name_code_dict

def reverse_dict(dictionary):
    """Reverse other map for converting from country code to country name
    :param dictionary: dictionary
    :returns reversed_dict: dictionary"""
    reversed_dict = dict(zip(dictionary.values(), dictionary.keys()))
    return reversed_dict

def add_country_name(df_data, code_name_dict):
    """Take df_data, add a column with country name and fill it using code_name_dict
    :param df_data: data frame
    :param code_name_dict: dictionary"""
    mapper = lambda x: code_name_dict[x]
    df_data.insert(loc=0, column='Country', value=df_data.loc[:, 'Code'].copy())
    df_data['Country'] = df_data['Country'].apply(mapper)

#add column with country name
name_code_dict = create_name_code_dict()
code_name_dict = reverse_dict(name_code_dict)
#add_country_name(ODA_Social_Infrastructure_wo_DAC, code_name_dict)


# For year 2015
add_country_name(ODA_Production_2018, code_name_dict)
# Out:
# C:\Users\prana\Anaconda3\lib\site-packages\ipykernel_launcher.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
len(ODA_Production_2018)
# Out:
# 38

# %%
ODA_Production_2018_cleaned = ODA_Production_2018

# %%
ODA_Production_2018_cleaned
# Out:
#                                                Country Code  Time  Millions($)
# 18                                           Australia  AUS  2018       222.30
# 37                                             Austria  AUT  2018        34.67
# 56                                             Belgium  BEL  2018        74.27
# 75                                              Canada  CAN  2018       247.69
# 92                                      Czech Republic  CZE  2018         5.09
# 111                                            Denmark  DNK  2018        81.19
# 130                                            Finland  FIN  2018        47.74
# 149                                             France  FRA  2018       856.46
# 168                                            Germany  DEU  2018      1103.60
# 188                                            Iceland  ISL  2018         3.80
# 207                                            Ireland  IRL  2018        31.56
# 226                                              Italy  ITA  2018       132.76
# 245                                              Japan  JPN  2018      1431.61
# 264                                  Republic of Korea  KOR  2018       394.53
# 280                                         Luxembourg  LUX  2018        27.17
# 299                                        Netherlands  NLD  2018       437.03
# 318                                        New Zealand  NZL  2018        37.68
# 337                                             Norway  NOR  2018       196.59
# 356                                           Portugal  PRT  2018         4.10
# 375                                              Spain  ESP  2018        70.47
# 394                                             Sweden  SWE  2018       292.16
# 413                                        Switzerland  CHE  2018       230.48
# 431                                             Turkey  TUR  2018        10.98
# 450  United Kingdom of Great Britain and Northern I...  GBR  2018      1046.29
# 469                           United States of America  USA  2018      1390.66
# 479                               United Arab Emirates  ARE  2018         9.59
# 504                                             Poland  POL  2018        34.56
# 510                                    Slovak Republic  SVK  2018         0.33
# 516                                            Estonia  EST  2018         0.37
# 523                                           Slovenia  SVN  2018         0.30
# 528                                            Hungary  HUN  2018        10.58
# 533                                          Lithuania  LTU  2018         0.13
# 537                                            Romania  ROU  2018         0.04
# 540                                 Russian Federation  RUS  2018        11.83
# 542                                           Bulgaria  BGR  2018         0.08
# 545                                             Latvia  LVA  2018         0.06
# 548                                       Saudi Arabia  SAU  2018        95.05
# 549                                             Cyprus  CYP  2018         0.10

# %%
def load_from_wbdata(countries, indicators, year_from, year_to):
    """Create data frame for given list of countries, indicators and dates using World Bank API
    :param countries: list of codes
    :param indicators: dict {ind_code : ind_name}
    :param year_from: starting year
    :param year_to: ending year
    :returns df_data: multi index data frame
    """
    data_date = (datetime.datetime(year_from, 1, 1), datetime.datetime(year_to, 1, 1))
    df_data = wbdata.get_dataframe(indicators, country=countries, data_date=data_date, convert_date=False)
    return df_data

#get GDP PPP data (NY.GDP.PCAP.PP.KD - GDP per capita, PPP (constant 2011 international $))
gdp_ppp = load_from_wbdata(countries_codes, {'NY.GDP.PCAP.PP.KD':'gdp_ppp'}, 2018, 2018)

# %%
gdp_ppp
# Out:
#                            gdp_ppp
# country
# United Arab Emirates  66616.050283
# Australia             45377.755143
# Austria               46260.382383
# Belgium               43582.128396
# Bulgaria              19320.751234
# Canada                44078.065596
# Switzerland           59317.323990
# Cyprus                34569.209865
# Czech Republic        33435.509181
# Germany               45936.182713
# Denmark               48419.437883
# Spain                 34830.544443
# Estonia               31035.393619
# Finland               42060.804122
# France                39555.544663
# United Kingdom        40522.246608
# Hungary               28464.560199
# Ireland               70855.327240
# Iceland               48605.577066
# Italy                 35828.486281
# Japan                 39293.691582
# Korea, Rep.           36776.519283
# Lithuania             31177.578046
# Luxembourg            96792.599595
# Latvia                26219.306470
# Netherlands           49787.072754
# Norway                65389.176979
# New Zealand           36351.574726
# Poland                28785.541423
# Portugal              28999.373093
# Romania               24538.077550
# Russian Federation    25629.281824
# Saudi Arabia          49100.656343
# Slovak Republic       31226.446443
# Slovenia              32728.401187
# Sweden                47717.664741
# Turkey                25357.722234
# United States         55719.119981

# %%
#reset index "country'
gdp_ppp.reset_index(level=['country'], inplace=True)

# %%
def add_country_code(df_data, name_code_dict):
    """Take df_data, add a column with country code and fill it using name_code_dict
    :param df_data: data frame
    :param name_code_dict: dictionary"""
    mapper = lambda x: name_code_dict[x]
    df_data.insert(loc=1, column='Code', value=df_data.loc[:, 'country'].copy())
    df_data['Code'] = df_data['Code'].apply(mapper)

#add column with country code
add_country_code(gdp_ppp, name_code_dict)

gdp_ppp
# Out:
#                  country Code       gdp_ppp
# 0   United Arab Emirates  ARE  66616.050283
# 1              Australia  AUS  45377.755143
# 2                Austria  AUT  46260.382383
# 3                Belgium  BEL  43582.128396
# 4               Bulgaria  BGR  19320.751234
# 5                 Canada  CAN  44078.065596
# 6            Switzerland  CHE  59317.323990
# 7                 Cyprus  CYP  34569.209865
# 8         Czech Republic  CZE  33435.509181
# 9                Germany  DEU  45936.182713
# 10               Denmark  DNK  48419.437883
# 11                 Spain  ESP  34830.544443
# 12               Estonia  EST  31035.393619
# 13               Finland  FIN  42060.804122
# 14                France  FRA  39555.544663
# 15        United Kingdom  GBR  40522.246608
# 16               Hungary  HUN  28464.560199
# 17               Ireland  IRL  70855.327240
# 18               Iceland  ISL  48605.577066
# 19                 Italy  ITA  35828.486281
# 20                 Japan  JPN  39293.691582
# 21           Korea, Rep.  KOR  36776.519283
# 22             Lithuania  LTU  31177.578046
# 23            Luxembourg  LUX  96792.599595
# 24                Latvia  LVA  26219.306470
# 25           Netherlands  NLD  49787.072754
# 26                Norway  NOR  65389.176979
# 27           New Zealand  NZL  36351.574726
# 28                Poland  POL  28785.541423
# 29              Portugal  PRT  28999.373093
# 30               Romania  ROU  24538.077550
# 31    Russian Federation  RUS  25629.281824
# 32          Saudi Arabia  SAU  49100.656343
# 33       Slovak Republic  SVK  31226.446443
# 34              Slovenia  SVN  32728.401187
# 35                Sweden  SWE  47717.664741
# 36                Turkey  TUR  25357.722234
# 37         United States  USA  55719.119981

# %% [markdown]
# <font size=4> <center> <br><br><br> <u> Regression Analysis   <br><br><br>

# %%
def merge_df_onCode(df_data1, df_data2):
    """Merge two data frames on Code column, drop double country column
    :param df_data1: data frame
    :param df_data2: data frame
    :returns df_joined: data frame"""
    df_joined = pd.merge(df_data1, df_data2, on='Code')
 #   df_joined.drop(['Country_y'], axis=1, inplace=True)
    return df_joined

#merge data 
combined_ODA_Production_2018_cleaned = merge_df_onCode(ODA_Production_2018_cleaned, gdp_ppp)

combined_ODA_Production_2018_cleaned
# Out:
#                                               Country Code  Time  Millions($)  \
# 0                                           Australia  AUS  2018       222.30
# 1                                             Austria  AUT  2018        34.67
# 2                                             Belgium  BEL  2018        74.27
# 3                                              Canada  CAN  2018       247.69
# 4                                      Czech Republic  CZE  2018         5.09
# 5                                             Denmark  DNK  2018        81.19
# 6                                             Finland  FIN  2018        47.74
# 7                                              France  FRA  2018       856.46
# 8                                             Germany  DEU  2018      1103.60
# 9                                             Iceland  ISL  2018         3.80
# 10                                            Ireland  IRL  2018        31.56
# 11                                              Italy  ITA  2018       132.76
# 12                                              Japan  JPN  2018      1431.61
# 13                                  Republic of Korea  KOR  2018       394.53
# 14                                         Luxembourg  LUX  2018        27.17
# 15                                        Netherlands  NLD  2018       437.03
# 16                                        New Zealand  NZL  2018        37.68
# 17                                             Norway  NOR  2018       196.59
# 18                                           Portugal  PRT  2018         4.10
# 19                                              Spain  ESP  2018        70.47
# 20                                             Sweden  SWE  2018       292.16
# 21                                        Switzerland  CHE  2018       230.48
# 22                                             Turkey  TUR  2018        10.98
# 23  United Kingdom of Great Britain and Northern I...  GBR  2018      1046.29
# 24                           United States of America  USA  2018      1390.66
# 25                               United Arab Emirates  ARE  2018         9.59
# 26                                             Poland  POL  2018        34.56
# 27                                    Slovak Republic  SVK  2018         0.33
# 28                                            Estonia  EST  2018         0.37
# 29                                           Slovenia  SVN  2018         0.30
# 30                                            Hungary  HUN  2018        10.58
# 31                                          Lithuania  LTU  2018         0.13
# 32                                            Romania  ROU  2018         0.04
# 33                                 Russian Federation  RUS  2018        11.83
# 34                                           Bulgaria  BGR  2018         0.08
# 35                                             Latvia  LVA  2018         0.06
# 36                                       Saudi Arabia  SAU  2018        95.05
# 37                                             Cyprus  CYP  2018         0.10
#
#                  country       gdp_ppp
# 0              Australia  45377.755143
# 1                Austria  46260.382383
# 2                Belgium  43582.128396
# 3                 Canada  44078.065596
# 4         Czech Republic  33435.509181
# 5                Denmark  48419.437883
# 6                Finland  42060.804122
# 7                 France  39555.544663
# 8                Germany  45936.182713
# 9                Iceland  48605.577066
# 10               Ireland  70855.327240
# 11                 Italy  35828.486281
# 12                 Japan  39293.691582
# 13           Korea, Rep.  36776.519283
# 14            Luxembourg  96792.599595
# 15           Netherlands  49787.072754
# 16           New Zealand  36351.574726
# 17                Norway  65389.176979
# 18              Portugal  28999.373093
# 19                 Spain  34830.544443
# 20                Sweden  47717.664741
# 21           Switzerland  59317.323990
# 22                Turkey  25357.722234
# 23        United Kingdom  40522.246608
# 24         United States  55719.119981
# 25  United Arab Emirates  66616.050283
# 26                Poland  28785.541423
# 27       Slovak Republic  31226.446443
# 28               Estonia  31035.393619
# 29              Slovenia  32728.401187
# 30               Hungary  28464.560199
# 31             Lithuania  31177.578046
# 32               Romania  24538.077550
# 33    Russian Federation  25629.281824
# 34              Bulgaria  19320.751234
# 35                Latvia  26219.306470
# 36          Saudi Arabia  49100.656343
# 37                Cyprus  34569.209865

# %%
combined_ODA_Production_2018_cleaned = combined_ODA_Production_2018_cleaned.drop(['country'], axis=1)

# %%
combined_ODA_Production_2018_cleaned
# Out:
#                                               Country Code  Time  Millions($)  \
# 0                                           Australia  AUS  2018       222.30
# 1                                             Austria  AUT  2018        34.67
# 2                                             Belgium  BEL  2018        74.27
# 3                                              Canada  CAN  2018       247.69
# 4                                      Czech Republic  CZE  2018         5.09
# 5                                             Denmark  DNK  2018        81.19
# 6                                             Finland  FIN  2018        47.74
# 7                                              France  FRA  2018       856.46
# 8                                             Germany  DEU  2018      1103.60
# 9                                             Iceland  ISL  2018         3.80
# 10                                            Ireland  IRL  2018        31.56
# 11                                              Italy  ITA  2018       132.76
# 12                                              Japan  JPN  2018      1431.61
# 13                                  Republic of Korea  KOR  2018       394.53
# 14                                         Luxembourg  LUX  2018        27.17
# 15                                        Netherlands  NLD  2018       437.03
# 16                                        New Zealand  NZL  2018        37.68
# 17                                             Norway  NOR  2018       196.59
# 18                                           Portugal  PRT  2018         4.10
# 19                                              Spain  ESP  2018        70.47
# 20                                             Sweden  SWE  2018       292.16
# 21                                        Switzerland  CHE  2018       230.48
# 22                                             Turkey  TUR  2018        10.98
# 23  United Kingdom of Great Britain and Northern I...  GBR  2018      1046.29
# 24                           United States of America  USA  2018      1390.66
# 25                               United Arab Emirates  ARE  2018         9.59
# 26                                             Poland  POL  2018        34.56
# 27                                    Slovak Republic  SVK  2018         0.33
# 28                                            Estonia  EST  2018         0.37
# 29                                           Slovenia  SVN  2018         0.30
# 30                                            Hungary  HUN  2018        10.58
# 31                                          Lithuania  LTU  2018         0.13
# 32                                            Romania  ROU  2018         0.04
# 33                                 Russian Federation  RUS  2018        11.83
# 34                                           Bulgaria  BGR  2018         0.08
# 35                                             Latvia  LVA  2018         0.06
# 36                                       Saudi Arabia  SAU  2018        95.05
# 37                                             Cyprus  CYP  2018         0.10
#
#          gdp_ppp
# 0   45377.755143
# 1   46260.382383
# 2   43582.128396
# 3   44078.065596
# 4   33435.509181
# 5   48419.437883
# 6   42060.804122
# 7   39555.544663
# 8   45936.182713
# 9   48605.577066
# 10  70855.327240
# 11  35828.486281
# 12  39293.691582
# 13  36776.519283
# 14  96792.599595
# 15  49787.072754
# 16  36351.574726
# 17  65389.176979
# 18  28999.373093
# 19  34830.544443
# 20  47717.664741
# 21  59317.323990
# 22  25357.722234
# 23  40522.246608
# 24  55719.119981
# 25  66616.050283
# 26  28785.541423
# 27  31226.446443
# 28  31035.393619
# 29  32728.401187
# 30  28464.560199
# 31  31177.578046
# 32  24538.077550
# 33  25629.281824
# 34  19320.751234
# 35  26219.306470
# 36  49100.656343
# 37  34569.209865

# %%
def show_scatterplot(df_data, variables, color, title, xlabel, ylabel):
    """Take df_data and plot for chosen columns in variables list
    :param df_data: data frame
    :param variables: list of strings
    :param color: string"""
    plt.scatter(x=df_data[variables[0]], y=df_data[variables[1]], color=color)
    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.show()
    
matplotlib.style.use('ggplot')
plot_combined_ODA_Production_2018_cleaned = show_scatterplot(combined_ODA_Production_2018_cleaned, ['gdp_ppp', 'Millions($)'], 'y',
                                    'Social Infrastruture Millions($) vs. GDP per capita (For year 2015)', 'GDP per capita (PPP $)',
                                    'Social Infrastruture (Millions($))')

# %%
combined_ODA_Production_2018_cleaned

#Infra = Infra.drop(Infra[Infra.LOCATION == 'MDA'].index)

combined_ODA_Production_2018_cleaned_wo_USA = combined_ODA_Production_2018_cleaned[combined_ODA_Production_2018_cleaned.Code != 'USA'] 
#  &  combined_ODA_Social_Infrastructure_2015_cleaned.Code != 'LUX'  ]

combined_ODA_Production_2018_cleaned_wo_JPN = combined_ODA_Production_2018_cleaned_wo_USA[combined_ODA_Production_2018_cleaned_wo_USA.Code != 'JPN'] 
    
combined_ODA_Production_2018_cleaned_wo_GBR = combined_ODA_Production_2018_cleaned_wo_JPN[combined_ODA_Production_2018_cleaned_wo_JPN.Code != 'GBR'] 
    
combined_ODA_Production_2018_cleaned_wo_DEU = combined_ODA_Production_2018_cleaned_wo_GBR[combined_ODA_Production_2018_cleaned_wo_GBR.Code != 'DEU'] 
    
combined_ODA_Production_2018_cleaned_wo_FRA = combined_ODA_Production_2018_cleaned_wo_DEU[combined_ODA_Production_2018_cleaned_wo_DEU.Code != 'FRA'] 

combined_ODA_Production_2018_cleaned_wo_LUX = combined_ODA_Production_2018_cleaned_wo_FRA[combined_ODA_Production_2018_cleaned_wo_FRA.Code != 'LUX'] 

combine_ODA_Production_2018 = combined_ODA_Production_2018_cleaned_wo_LUX

# %%
combine_ODA_Production_2018
# Out:
#                  Country Code  Time  Millions($)       gdp_ppp
# 0              Australia  AUS  2018       222.30  45377.755143
# 1                Austria  AUT  2018        34.67  46260.382383
# 2                Belgium  BEL  2018        74.27  43582.128396
# 3                 Canada  CAN  2018       247.69  44078.065596
# 4         Czech Republic  CZE  2018         5.09  33435.509181
# 5                Denmark  DNK  2018        81.19  48419.437883
# 6                Finland  FIN  2018        47.74  42060.804122
# 9                Iceland  ISL  2018         3.80  48605.577066
# 10               Ireland  IRL  2018        31.56  70855.327240
# 11                 Italy  ITA  2018       132.76  35828.486281
# 13     Republic of Korea  KOR  2018       394.53  36776.519283
# 15           Netherlands  NLD  2018       437.03  49787.072754
# 16           New Zealand  NZL  2018        37.68  36351.574726
# 17                Norway  NOR  2018       196.59  65389.176979
# 18              Portugal  PRT  2018         4.10  28999.373093
# 19                 Spain  ESP  2018        70.47  34830.544443
# 20                Sweden  SWE  2018       292.16  47717.664741
# 21           Switzerland  CHE  2018       230.48  59317.323990
# 22                Turkey  TUR  2018        10.98  25357.722234
# 25  United Arab Emirates  ARE  2018         9.59  66616.050283
# 26                Poland  POL  2018        34.56  28785.541423
# 27       Slovak Republic  SVK  2018         0.33  31226.446443
# 28               Estonia  EST  2018         0.37  31035.393619
# 29              Slovenia  SVN  2018         0.30  32728.401187
# 30               Hungary  HUN  2018        10.58  28464.560199
# 31             Lithuania  LTU  2018         0.13  31177.578046
# 32               Romania  ROU  2018         0.04  24538.077550
# 33    Russian Federation  RUS  2018        11.83  25629.281824
# 34              Bulgaria  BGR  2018         0.08  19320.751234
# 35                Latvia  LVA  2018         0.06  26219.306470
# 36          Saudi Arabia  SAU  2018        95.05  49100.656343
# 37                Cyprus  CYP  2018         0.10  34569.209865

# %%
#plot_combine_ODA_Production_2018


matplotlib.style.use('ggplot')
plot_combine_ODA_Production_2018 = show_scatterplot(combine_ODA_Production_2018, ['gdp_ppp', 'Millions($)'], 'y',
                                    'Social Infrastruture Millions($) vs. GDP per capita (For year 2015)', 'GDP per capita (PPP $)',
                                    'Social Infrastruture (Millions($))')
plot_combine_ODA_Production_2018

# %% [markdown]
# <font size = 3> <br> <br> <center> <i> Pretty much linear except a few outliers. Taking log to reduce the skewness <br>

# %%
combine_ODA_Production_2018
# Out:
#                  Country Code  Time  Millions($)       gdp_ppp
# 0              Australia  AUS  2018       222.30  45377.755143
# 1                Austria  AUT  2018        34.67  46260.382383
# 2                Belgium  BEL  2018        74.27  43582.128396
# 3                 Canada  CAN  2018       247.69  44078.065596
# 4         Czech Republic  CZE  2018         5.09  33435.509181
# 5                Denmark  DNK  2018        81.19  48419.437883
# 6                Finland  FIN  2018        47.74  42060.804122
# 9                Iceland  ISL  2018         3.80  48605.577066
# 10               Ireland  IRL  2018        31.56  70855.327240
# 11                 Italy  ITA  2018       132.76  35828.486281
# 13     Republic of Korea  KOR  2018       394.53  36776.519283
# 15           Netherlands  NLD  2018       437.03  49787.072754
# 16           New Zealand  NZL  2018        37.68  36351.574726
# 17                Norway  NOR  2018       196.59  65389.176979
# 18              Portugal  PRT  2018         4.10  28999.373093
# 19                 Spain  ESP  2018        70.47  34830.544443
# 20                Sweden  SWE  2018       292.16  47717.664741
# 21           Switzerland  CHE  2018       230.48  59317.323990
# 22                Turkey  TUR  2018        10.98  25357.722234
# 25  United Arab Emirates  ARE  2018         9.59  66616.050283
# 26                Poland  POL  2018        34.56  28785.541423
# 27       Slovak Republic  SVK  2018         0.33  31226.446443
# 28               Estonia  EST  2018         0.37  31035.393619
# 29              Slovenia  SVN  2018         0.30  32728.401187
# 30               Hungary  HUN  2018        10.58  28464.560199
# 31             Lithuania  LTU  2018         0.13  31177.578046
# 32               Romania  ROU  2018         0.04  24538.077550
# 33    Russian Federation  RUS  2018        11.83  25629.281824
# 34              Bulgaria  BGR  2018         0.08  19320.751234
# 35                Latvia  LVA  2018         0.06  26219.306470
# 36          Saudi Arabia  SAU  2018        95.05  49100.656343
# 37                Cyprus  CYP  2018         0.10  34569.209865

# %%
ODA_combine_ODA_Production_2018_gdp_ppp_log = combine_ODA_Production_2018

# %%
ODA_combine_ODA_Production_2018_gdp_ppp_log['log_value'] = np.log(ODA_combine_ODA_Production_2018_gdp_ppp_log['gdp_ppp'])
# Out:
# C:\Users\prana\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
ODA_combine_ODA_Production_2018_gdp_ppp_log
# Out:
#                  Country Code  Time  Millions($)       gdp_ppp  log_value
# 0              Australia  AUS  2018       222.30  45377.755143  10.722777
# 1                Austria  AUT  2018        34.67  46260.382383  10.742041
# 2                Belgium  BEL  2018        74.27  43582.128396  10.682402
# 3                 Canada  CAN  2018       247.69  44078.065596  10.693718
# 4         Czech Republic  CZE  2018         5.09  33435.509181  10.417374
# 5                Denmark  DNK  2018        81.19  48419.437883  10.787657
# 6                Finland  FIN  2018        47.74  42060.804122  10.646872
# 9                Iceland  ISL  2018         3.80  48605.577066  10.791494
# 10               Ireland  IRL  2018        31.56  70855.327240  11.168395
# 11                 Italy  ITA  2018       132.76  35828.486281  10.486499
# 13     Republic of Korea  KOR  2018       394.53  36776.519283  10.512615
# 15           Netherlands  NLD  2018       437.03  49787.072754  10.815511
# 16           New Zealand  NZL  2018        37.68  36351.574726  10.500993
# 17                Norway  NOR  2018       196.59  65389.176979  11.088112
# 18              Portugal  PRT  2018         4.10  28999.373093  10.275029
# 19                 Spain  ESP  2018        70.47  34830.544443  10.458250
# 20                Sweden  SWE  2018       292.16  47717.664741  10.773057
# 21           Switzerland  CHE  2018       230.48  59317.323990  10.990657
# 22                Turkey  TUR  2018        10.98  25357.722234  10.140839
# 25  United Arab Emirates  ARE  2018         9.59  66616.050283  11.106701
# 26                Poland  POL  2018        34.56  28785.541423  10.267629
# 27       Slovak Republic  SVK  2018         0.33  31226.446443  10.349021
# 28               Estonia  EST  2018         0.37  31035.393619  10.342884
# 29              Slovenia  SVN  2018         0.30  32728.401187  10.395999
# 30               Hungary  HUN  2018        10.58  28464.560199  10.256415
# 31             Lithuania  LTU  2018         0.13  31177.578046  10.347454
# 32               Romania  ROU  2018         0.04  24538.077550  10.107981
# 33    Russian Federation  RUS  2018        11.83  25629.281824  10.151491
# 34              Bulgaria  BGR  2018         0.08  19320.751234   9.868935
# 35                Latvia  LVA  2018         0.06  26219.306470  10.174251
# 36          Saudi Arabia  SAU  2018        95.05  49100.656343  10.801628
# 37                Cyprus  CYP  2018         0.10  34569.209865  10.450719

# %%
ODA_combine_ODA_Production_2018_gdp_ppp_log = ODA_combine_ODA_Production_2018_gdp_ppp_log.rename(columns={"log_value": "gdp_ppp_log"})

# %%
ODA_combine_ODA_Production_2018_gdp_ppp_log
# Out:
#                  Country Code  Time  Millions($)       gdp_ppp  gdp_ppp_log
# 0              Australia  AUS  2018       222.30  45377.755143    10.722777
# 1                Austria  AUT  2018        34.67  46260.382383    10.742041
# 2                Belgium  BEL  2018        74.27  43582.128396    10.682402
# 3                 Canada  CAN  2018       247.69  44078.065596    10.693718
# 4         Czech Republic  CZE  2018         5.09  33435.509181    10.417374
# 5                Denmark  DNK  2018        81.19  48419.437883    10.787657
# 6                Finland  FIN  2018        47.74  42060.804122    10.646872
# 9                Iceland  ISL  2018         3.80  48605.577066    10.791494
# 10               Ireland  IRL  2018        31.56  70855.327240    11.168395
# 11                 Italy  ITA  2018       132.76  35828.486281    10.486499
# 13     Republic of Korea  KOR  2018       394.53  36776.519283    10.512615
# 15           Netherlands  NLD  2018       437.03  49787.072754    10.815511
# 16           New Zealand  NZL  2018        37.68  36351.574726    10.500993
# 17                Norway  NOR  2018       196.59  65389.176979    11.088112
# 18              Portugal  PRT  2018         4.10  28999.373093    10.275029
# 19                 Spain  ESP  2018        70.47  34830.544443    10.458250
# 20                Sweden  SWE  2018       292.16  47717.664741    10.773057
# 21           Switzerland  CHE  2018       230.48  59317.323990    10.990657
# 22                Turkey  TUR  2018        10.98  25357.722234    10.140839
# 25  United Arab Emirates  ARE  2018         9.59  66616.050283    11.106701
# 26                Poland  POL  2018        34.56  28785.541423    10.267629
# 27       Slovak Republic  SVK  2018         0.33  31226.446443    10.349021
# 28               Estonia  EST  2018         0.37  31035.393619    10.342884
# 29              Slovenia  SVN  2018         0.30  32728.401187    10.395999
# 30               Hungary  HUN  2018        10.58  28464.560199    10.256415
# 31             Lithuania  LTU  2018         0.13  31177.578046    10.347454
# 32               Romania  ROU  2018         0.04  24538.077550    10.107981
# 33    Russian Federation  RUS  2018        11.83  25629.281824    10.151491
# 34              Bulgaria  BGR  2018         0.08  19320.751234     9.868935
# 35                Latvia  LVA  2018         0.06  26219.306470    10.174251
# 36          Saudi Arabia  SAU  2018        95.05  49100.656343    10.801628
# 37                Cyprus  CYP  2018         0.10  34569.209865    10.450719

# %%
#take log from GDP values
#health_gdp_ppp_log = take_log(combined_health_gdp_ppp, ['gdp_ppp'])

#plot with GDP log
ODA_combine_ODA_Production_2018_gdp_ppp_log_plot = show_scatterplot(ODA_combine_ODA_Production_2018_gdp_ppp_log, ['gdp_ppp_log', 'Millions($)'], 'm', 
                                         'Health Expenditure vs. GDP per capita (log)', 'GDP per capita (PPP $) (log)',
                                    'Health Expenditure (points)')

# %%
ODA_Production_gdp_ppp_log = ODA_combine_ODA_Production_2018_gdp_ppp_log

# %%
ODA_Production_gdp_ppp_log = ODA_Production_gdp_ppp_log.rename(columns={"Millions($)": "Millions"})

# %%
ODA_Production_gdp_ppp_log
# Out:
#                  Country Code  Time  Millions       gdp_ppp  gdp_ppp_log
# 0              Australia  AUS  2018    222.30  45377.755143    10.722777
# 1                Austria  AUT  2018     34.67  46260.382383    10.742041
# 2                Belgium  BEL  2018     74.27  43582.128396    10.682402
# 3                 Canada  CAN  2018    247.69  44078.065596    10.693718
# 4         Czech Republic  CZE  2018      5.09  33435.509181    10.417374
# 5                Denmark  DNK  2018     81.19  48419.437883    10.787657
# 6                Finland  FIN  2018     47.74  42060.804122    10.646872
# 9                Iceland  ISL  2018      3.80  48605.577066    10.791494
# 10               Ireland  IRL  2018     31.56  70855.327240    11.168395
# 11                 Italy  ITA  2018    132.76  35828.486281    10.486499
# 13     Republic of Korea  KOR  2018    394.53  36776.519283    10.512615
# 15           Netherlands  NLD  2018    437.03  49787.072754    10.815511
# 16           New Zealand  NZL  2018     37.68  36351.574726    10.500993
# 17                Norway  NOR  2018    196.59  65389.176979    11.088112
# 18              Portugal  PRT  2018      4.10  28999.373093    10.275029
# 19                 Spain  ESP  2018     70.47  34830.544443    10.458250
# 20                Sweden  SWE  2018    292.16  47717.664741    10.773057
# 21           Switzerland  CHE  2018    230.48  59317.323990    10.990657
# 22                Turkey  TUR  2018     10.98  25357.722234    10.140839
# 25  United Arab Emirates  ARE  2018      9.59  66616.050283    11.106701
# 26                Poland  POL  2018     34.56  28785.541423    10.267629
# 27       Slovak Republic  SVK  2018      0.33  31226.446443    10.349021
# 28               Estonia  EST  2018      0.37  31035.393619    10.342884
# 29              Slovenia  SVN  2018      0.30  32728.401187    10.395999
# 30               Hungary  HUN  2018     10.58  28464.560199    10.256415
# 31             Lithuania  LTU  2018      0.13  31177.578046    10.347454
# 32               Romania  ROU  2018      0.04  24538.077550    10.107981
# 33    Russian Federation  RUS  2018     11.83  25629.281824    10.151491
# 34              Bulgaria  BGR  2018      0.08  19320.751234     9.868935
# 35                Latvia  LVA  2018      0.06  26219.306470    10.174251
# 36          Saudi Arabia  SAU  2018     95.05  49100.656343    10.801628
# 37                Cyprus  CYP  2018      0.10  34569.209865    10.450719

# %%
#perform OLS 
model_ODA_Production_gdp_ppp_log = smf.ols(formula='Millions ~ gdp_ppp_log', data=ODA_Production_gdp_ppp_log).fit()
model_ODA_Production_gdp_ppp_log.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               Millions   R-squared:                       0.190
# Model:                            OLS   Adj. R-squared:                  0.163
# Method:                 Least Squares   F-statistic:                     7.025
# Date:                Sun, 12 Apr 2020   Prob (F-statistic):             0.0127
# Time:                        17:38:58   Log-Likelihood:                -195.04
# No. Observations:                  32   AIC:                             394.1
# Df Residuals:                      30   BIC:                             397.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept   -1661.1825    659.109     -2.520      0.017   -3007.263    -315.102
# gdp_ppp_log   165.6490     62.500      2.650      0.013      38.007     293.291
# ==============================================================================
# Omnibus:                       15.364   Durbin-Watson:                   1.255
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               16.753
# Skew:                           1.422   Prob(JB):                     0.000230
# Kurtosis:                       5.117   Cond. No.                         358.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
#perform OLS 
model_ODA_Production_gdp_ppp_log = smf.ols(formula='gdp_ppp_log  ~ Millions', data=ODA_Production_gdp_ppp_log).fit()
model_ODA_Production_gdp_ppp_log.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            gdp_ppp_log   R-squared:                       0.190
# Model:                            OLS   Adj. R-squared:                  0.163
# Method:                 Least Squares   F-statistic:                     7.025
# Date:                Sun, 12 Apr 2020   Prob (F-statistic):             0.0127
# Time:                        17:39:58   Log-Likelihood:                -4.9268
# No. Observations:                  32   AIC:                             13.85
# Df Residuals:                      30   BIC:                             16.79
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     10.4438      0.063    165.073      0.000      10.315      10.573
# Millions       0.0011      0.000      2.650      0.013       0.000       0.002
# ==============================================================================
# Omnibus:                        2.593   Durbin-Watson:                   1.729
# Prob(Omnibus):                  0.273   Jarque-Bera (JB):                1.698
# Skew:                           0.558   Prob(JB):                        0.428
# Kurtosis:                       3.164   Cond. No.                         180.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """
