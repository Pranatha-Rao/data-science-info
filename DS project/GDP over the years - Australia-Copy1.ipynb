# %%
import wbdata
import pandas as pd
import pycountry
import wbdata
import datetime
import matplotlib.pyplot as plt

 

countries = ["AUS"]

indicators1 = { 
              'BX.KLT.DINV.WD.GD.ZS': 'FDI',
              'NV.IND.MANF.ZS': 'Manufacturing',
              'EG.ELC.NGAS.ZS': 'Electricity from Natural Gas',
              'SL.SRV.EMPL.ZS': 'Employment in Services',
              'SH.XPD.PVTD.PC.CD': 'Domestic health expenditure',
              'SH.XPD.CHEX.PC.CD': 'Current health exp per capita',
              'SH.XPD.CHEX.PC.CD': 'Health per capita'
            
              
               }

data_date = (datetime.datetime(2000, 1, 1), datetime.datetime(2015, 1, 1))
 
 
df1 = wbdata.get_dataframe(indicators1, country=countries, data_date=data_date ,convert_date=False)

# %%
df1
# Out:
#            FDI  Manufacturing  Electricity from Natural Gas  \
# date
# 2015  3.469188       6.290283                     20.795478
# 2014  4.306384       6.358217                     21.909741
# 2013  3.425824       6.597965                     20.452606
# 2012  3.722172       7.030140                     19.343072
# 2011  4.693724       7.351573                     19.297223
# 2010  3.072119       7.989865                     17.646873
# 2009  3.091518       8.440060                     16.151877
# 2008  4.284650       9.195600                     14.380454
# 2007  5.209250       9.280844                     13.107717
# 2006  4.095024       9.886796                      9.765090
# 2005 -3.618815      10.336080                     10.424048
# 2004  7.005444      10.890447                     13.548308
# 2003  1.926147      10.870331                     13.317255
# 2002  3.713762      10.559587                     13.954736
# ...

# %%
df1.insert(0, "Country code","AUS")

# %%
df1
# Out:
#      Country code       FDI  Manufacturing  Electricity from Natural Gas  \
# date
# 2015          AUS  3.469188       6.290283                     20.795478
# 2014          AUS  4.306384       6.358217                     21.909741
# 2013          AUS  3.425824       6.597965                     20.452606
# 2012          AUS  3.722172       7.030140                     19.343072
# 2011          AUS  4.693724       7.351573                     19.297223
# 2010          AUS  3.072119       7.989865                     17.646873
# 2009          AUS  3.091518       8.440060                     16.151877
# 2008          AUS  4.284650       9.195600                     14.380454
# 2007          AUS  5.209250       9.280844                     13.107717
# 2006          AUS  4.095024       9.886796                      9.765090
# 2005          AUS -3.618815      10.336080                     10.424048
# 2004          AUS  7.005444      10.890447                     13.548308
# ...

# %%
df1.reset_index(inplace = True)

# %%
df1
# Out:
#     date Country code       FDI  Manufacturing  Electricity from Natural Gas  \
# 0   2015          AUS  3.469188       6.290283                     20.795478
# 1   2014          AUS  4.306384       6.358217                     21.909741
# 2   2013          AUS  3.425824       6.597965                     20.452606
# 3   2012          AUS  3.722172       7.030140                     19.343072
# 4   2011          AUS  4.693724       7.351573                     19.297223
# 5   2010          AUS  3.072119       7.989865                     17.646873
# 6   2009          AUS  3.091518       8.440060                     16.151877
# 7   2008          AUS  4.284650       9.195600                     14.380454
# 8   2007          AUS  5.209250       9.280844                     13.107717
# 9   2006          AUS  4.095024       9.886796                      9.765090
# 10  2005          AUS -3.618815      10.336080                     10.424048
# ...

# %%
#grab indicators above for countires above and load into data frame
#df = wbdata.get_dataframe(indicators, country=countries, data_date=data_date ,convert_date=False)

data_date = (datetime.datetime(2002, 1, 1), datetime.datetime(2017, 1, 1))
indicators2 = {'NY.GDP.PCAP.CD': 'GDP per Capita after 2 years'}

# %%
#grab indicators above for countires above and load into data frame
df2 = wbdata.get_dataframe(indicators2, country=countries, data_date=data_date ,convert_date=False)

# %%
df2
# Out:
#       GDP per Capita after 2 years
# date
# 2017                  54066.471269
# 2016                  49971.131456
# 2015                  56755.721712
# 2014                  62510.791171
# 2013                  68150.107041
# 2012                  68012.147901
# 2011                  62517.833747
# 2010                  52022.125596
# 2009                  42772.359166
# 2008                  49601.656708
# 2007                  40960.054495
# 2006                  36044.922811
# 2005                  33999.242858
# 2004                  30430.676437
# 2003                  23447.031001
# 2002                  20082.483267

# %%
df2.reset_index(inplace = True)

# %%
df2 = df2.drop(['date'],axis = 1)

# %%
df2
# Out:
#     GDP per Capita after 2 years
# 0                   54066.471269
# 1                   49971.131456
# 2                   56755.721712
# 3                   62510.791171
# 4                   68150.107041
# 5                   68012.147901
# 6                   62517.833747
# 7                   52022.125596
# 8                   42772.359166
# 9                   49601.656708
# 10                  40960.054495
# 11                  36044.922811
# 12                  33999.242858
# 13                  30430.676437
# 14                  23447.031001
# 15                  20082.483267

# %%
#Get GDP after 3 years

data_date = (datetime.datetime(2003, 1, 1), datetime.datetime(2018, 1, 1))

#grab indicators above for countires above and load into data frame
#df3 = wbdata.get_dataframe(indicators, country=countries, data_date=data_date ,convert_date=False)

indicators3 = {'NY.GDP.PCAP.CD': 'GDP per Capita after 3 years'}

# %%
#grab indicators above for countires above and load into data frame
df3 = wbdata.get_dataframe(indicators3, country=countries, data_date=data_date ,convert_date=False)

# %%
df3.reset_index(inplace = True)

# %%
df3 = df3.drop(['date'],axis = 1)

# %%
#Get GDP after 4 years

data_date = (datetime.datetime(2004, 1, 1), datetime.datetime(2019, 1, 1))



indicators4 = {'NY.GDP.PCAP.CD': 'GDP per Capita after 4 years'}

# %%
#grab indicators above for countires above and load into data frame
df4 = wbdata.get_dataframe(indicators4, country=countries, data_date=data_date ,convert_date=False)

# %%
df4.reset_index(inplace = True)

# %%
df4 = df4.drop(['date'],axis = 1)

# %%
df4
# Out:
#     GDP per Capita after 4 years
# 0                            NaN
# 1                   57373.686684
# 2                   54066.471269
# 3                   49971.131456
# 4                   56755.721712
# 5                   62510.791171
# 6                   68150.107041
# 7                   68012.147901
# 8                   62517.833747
# 9                   52022.125596
# 10                  42772.359166
# 11                  49601.656708
# 12                  40960.054495
# 13                  36044.922811
# 14                  33999.242858
# 15                  30430.676437

# %%
df3
# Out:
#     GDP per Capita after 3 years
# 0                   57373.686684
# 1                   54066.471269
# 2                   49971.131456
# 3                   56755.721712
# 4                   62510.791171
# 5                   68150.107041
# 6                   68012.147901
# 7                   62517.833747
# 8                   52022.125596
# 9                   42772.359166
# 10                  49601.656708
# 11                  40960.054495
# 12                  36044.922811
# 13                  33999.242858
# 14                  30430.676437
# 15                  23447.031001

# %%
df4
# Out:
#     GDP per Capita after 4 years
# 0                            NaN
# 1                   57373.686684
# 2                   54066.471269
# 3                   49971.131456
# 4                   56755.721712
# 5                   62510.791171
# 6                   68150.107041
# 7                   68012.147901
# 8                   62517.833747
# 9                   52022.125596
# 10                  42772.359166
# 11                  49601.656708
# 12                  40960.054495
# 13                  36044.922811
# 14                  33999.242858
# 15                  30430.676437

# %%
# replacing na values in college with No college 
#nba["College"].fillna("No College", inplace = True)
df4 = df4["GDP per Capita after 4 years"].fillna("57373.7")

# %%
df_joined = pd.merge(df1,df2,left_index=True, right_index=True)
df_joined
# Out:
#     date Country code       FDI  Manufacturing  Electricity from Natural Gas  \
# 0   2015          AUS  3.469188       6.290283                     20.795478
# 1   2014          AUS  4.306384       6.358217                     21.909741
# 2   2013          AUS  3.425824       6.597965                     20.452606
# 3   2012          AUS  3.722172       7.030140                     19.343072
# 4   2011          AUS  4.693724       7.351573                     19.297223
# 5   2010          AUS  3.072119       7.989865                     17.646873
# 6   2009          AUS  3.091518       8.440060                     16.151877
# 7   2008          AUS  4.284650       9.195600                     14.380454
# 8   2007          AUS  5.209250       9.280844                     13.107717
# 9   2006          AUS  4.095024       9.886796                      9.765090
# 10  2005          AUS -3.618815      10.336080                     10.424048
# ...

# %%
df_joined1 = pd.merge(df_joined ,df3,left_index=True, right_index=True)

# %%
df_joined2 = pd.merge(df_joined1 ,df4,left_index=True, right_index=True)

# %%
df_joined2
# Out:
#     date Country code       FDI  Manufacturing  Electricity from Natural Gas  \
# 0   2015          AUS  3.469188       6.290283                     20.795478
# 1   2014          AUS  4.306384       6.358217                     21.909741
# 2   2013          AUS  3.425824       6.597965                     20.452606
# 3   2012          AUS  3.722172       7.030140                     19.343072
# 4   2011          AUS  4.693724       7.351573                     19.297223
# 5   2010          AUS  3.072119       7.989865                     17.646873
# 6   2009          AUS  3.091518       8.440060                     16.151877
# 7   2008          AUS  4.284650       9.195600                     14.380454
# 8   2007          AUS  5.209250       9.280844                     13.107717
# 9   2006          AUS  4.095024       9.886796                      9.765090
# 10  2005          AUS -3.618815      10.336080                     10.424048
# ...

# %%
df_joined.corr()
# Out:
#                                    FDI  Manufacturing  \
# FDI                           1.000000      -0.149732
# Manufacturing                -0.149732       1.000000
# Electricity from Natural Gas  0.241447      -0.925818
# Employment in Services        0.051944      -0.928605
# Domestic health expenditure   0.163478      -0.948956
# Health per capita             0.170443      -0.945233
# GDP per Capita after 2 years  0.095982      -0.809637
#
#                               Electricity from Natural Gas  \
# FDI                                               0.241447
# Manufacturing                                    -0.925818
# Electricity from Natural Gas                      1.000000
# Employment in Services                            0.894885
# Domestic health expenditure                       0.885003
# Health per capita                                 0.880812
# GDP per Capita after 2 years                      0.748143
#
# ...

# %%
import seaborn as sns
#plotting the heat map of the correlation
plt.figure(figsize=(20,7))
sns.heatmap(df_joined.corr(), annot=True)

# %%
#Using OLS for finding the p value and t statistics 
import statsmodels.api as sm

model = sm.OLS(df_joined['GDP per Capita after 2 years'], df_joined[['FDI', 'Manufacturing', 'Electricity from Natural Gas','Employment in Services', 'Domestic health expenditure', 'Health per capita']]).fit()

# Print out the statistics
model.summary()
# Out:
# C:\Users\prana\Anaconda3\lib\site-packages\scipy\stats\stats.py:1535: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=16
#   "anyway, n=%i" % int(n))
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                       OLS Regression Results
# ...
# Dep. Variable:     GDP per Capita after 2 years   R-squared (uncentered):                   0.990
# Model:                                      OLS   Adj. R-squared (uncentered):              0.983
# Method:                           Least Squares   F-statistic:                              157.2
# Date:                          Fri, 17 Apr 2020   Prob (F-statistic):                    2.62e-09
# Time:                                  10:21:50   Log-Likelihood:                         -159.10
# No. Observations:                            16   AIC:                                      330.2
# Df Residuals:                                10   BIC:                                      334.8
# ...

# %% [markdown]
# #### For any modelling task, the hypothesis is that there is some correlation between the features and the target. The null hypothesis is therefore the opposite: there is no correlation between the features and the target.

# %% [markdown]
# Considering the significance value of 0.05.
#
# 1. The **FDI** has the p-value 0.419, which is greater and this provides less evidence against the null hypothesis and it    is not a significant feature.
# 2. The **Manufacturing** has the p-value 0.896, which is greater and this provides less evidence against the null hypothesis and it    is not a significant feature.
# 3. The **Electricity from Natural Gas** has the p-value 0.871,which is greater and this provides less evidence against the null hypothesis and it    is not a significant feature.
# 4. The **Employment in Services** has the p-value 0.874, which is greater and this provides less evidence against the null hypothesis and it    is not a significant feature.
# 5. The **Domestic health expenditure** has the p-value 0.021, which is less and this provides greater evidence against the null hypothesis and      it is a significant feature.
# 6. The **Health per capita** has the p-value 0.008, which is less and this provides greater evidence against the null hypothesis and      it is a significant feature.

# %% [markdown]
# ### ```OLS linear regression```

# %% [markdown]
# Data is split into 3 parts
#
# Taining data set = 80.75%
#
# Validation data set = 14.25%
#
# Test data set = 5%

# %%
from sklearn.model_selection import  train_test_split

X = df_joined[ ['Domestic health expenditure', 'Health per capita']]

y = df_joined['GDP per Capita after 2 years']

X_t, X_test, y_t, y_test = train_test_split(X, y, test_size=0.05, random_state=1)

X_train, X_val, y_train, y_val = train_test_split(X_t, y_t, test_size=0.15, random_state=1)

# %%
from sklearn.model_selection import  train_test_split
from sklearn.metrics import r2_score 
from sklearn.linear_model import LinearRegression
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score

# %%
# Create linear regression object
regr = linear_model.LinearRegression()

# Train the model using the training sets
regr.fit(X_train,y_train)

# Make predictions using the testing set
y_pred = regr.predict(X_train)

# %%
#training Data
# The coefficients
print('Coefficients: \n', regr.coef_)
# The mean squared error
print('Mean squared error: %.2f'% mean_squared_error(y_train, y_pred))
# The coefficient of determination: 1 is perfect prediction
print('Coefficient of determination: %.2f'% r2_score(y_train, y_pred))
# Out:
# Coefficients:
#  [-86.44963574  36.42232811]
# Mean squared error: 25235381.19
# Coefficient of determination: 0.87

# %%
# Make predictions using the testing set
y_pred = regr.predict(X_val)

# The coefficients
print('Coefficients: \n', regr.coef_)
# The mean squared error
print('Mean squared error: %.2f'% mean_squared_error(y_val, y_pred))
# The coefficient of determination: 1 is perfect prediction
print('Coefficient of determination: %.2f'% r2_score(y_val, y_pred))
# Out:
# Coefficients:
#  [-86.44963574  36.42232811]
# Mean squared error: 64446737.49
# Coefficient of determination: 0.76
